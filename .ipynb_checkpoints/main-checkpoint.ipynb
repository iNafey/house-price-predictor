# %% [markdown]
# # Data Cleaning and Transformation
# ## Initial Input

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("Manhattan12.csv", header = 4)
data.shape
# Out:
# (27395, 21)

# %%
pd.set_option('display.width', 1080)
pd.set_option('display.max_columns', None)

# %% [markdown]
# The shape of the data is (27399, 21) as shown above. This means that there is initially 27399 rows and 21 columns of data.

# %% [markdown]
# ## Column Renaming

# %%
data.columns
# Out:
# Index(['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY', 'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT', 'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APART\nMENT\nNUMBER', 'ZIP CODE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT', 'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE', 'SALE\nPRICE', 'SALE DATE'], dtype='object')

# %% [markdown]
# Columns incorrectly named: 'APART\nMENT\nNUMBER', 'SALE\nPRICE'

# %%
data = data.rename(columns = {"APART\nMENT\nNUMBER":"APARTMENT NUMBER", "SALE\nPRICE":"SALE PRICE"})

# %%
data.dtypes
# Out:
# BOROUGH                            int64
# NEIGHBORHOOD                      object
# BUILDING CLASS CATEGORY           object
# TAX CLASS AT PRESENT              object
# BLOCK                              int64
# LOT                                int64
# EASE-MENT                         object
# BUILDING CLASS AT PRESENT         object
# ADDRESS                           object
# APARTMENT NUMBER                  object
# ZIP CODE                           int64
# RESIDENTIAL UNITS                 object
# COMMERCIAL UNITS                   int64
# TOTAL UNITS                       object
# LAND SQUARE FEET                  object
# GROSS SQUARE FEET                 object
# YEAR BUILT                         int64
# TAX CLASS AT TIME OF SALE          int64
# BUILDING CLASS AT TIME OF SALE    object
# SALE PRICE                        object
# SALE DATE                         object
# dtype: object

# %% [markdown]
# Column names are now correct!

# %% [markdown]
# ## Create List of Categoricals and Numerics

# %%
numericals = ['LAND SQUARE FEET', 'GROSS SQUARE FEET', 'SALE PRICE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS']
categoricals = ['NEIGHBORHOOD', 'BUILDING CLASS CATEGORY', 'TAX CLASS AT PRESENT', 'EASE-MENT',
                'BUILDING CLASS AT PRESENT', 'APARTMENT NUMBER', 'TAX CLASS AT TIME OF SALE', 
                'BUILDING CLASS AT TIME OF SALE', 'BLOCK', 'LOT', 'ADDRESS', 'ZIP CODE', 'YEAR BUILT', 'SALE DATE']

# %% [markdown]
# Two lists have been made which contains all the column names. Each column is either in the numerical or categorical list. They are split as followed:

# %%
print("Numericals:", str(numericals), "\nCategoricals:", str(categoricals))
# Out:
# Numericals: ['LAND SQUARE FEET', 'GROSS SQUARE FEET', 'SALE PRICE', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS']
# Categoricals: ['NEIGHBORHOOD', 'BUILDING CLASS CATEGORY', 'TAX CLASS AT PRESENT', 'EASE-MENT', 'BUILDING CLASS AT PRESENT', 'APARTMENT NUMBER', 'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE', 'BLOCK', 'LOT', 'ADDRESS', 'ZIP CODE', 'YEAR BUILT', 'SALE DATE']

# %% [markdown]
# ## Fixing Numerical Values

# %%
for i in numericals:
    if data[i].dtype not in ["int64"]:
        data[i] = data[i].apply(lambda a: a.replace("$", "").replace(",","")).astype("int64")

# %% [markdown]
# All values that should be numerical but aren't have now been converted to "int64"

# %% [markdown]
# ## Converting Sale Date to datetime

# %%
data['SALE DATE'] = pd.to_datetime(data['SALE DATE'], dayfirst=True)

# %% [markdown]
# "SALE DATE" is now in datetime

# %% [markdown]
# ## Fixing Categoricals

# %%
for i in categoricals:
    data[i] = data[i].replace(to_replace = r'[\s]+', value = "", regex = True)
    data[i] = data[i].replace(to_replace = "",  value = np.nan)

# %% [markdown]
# ## Replacing Zeros

# %%
for i in numericals:
    data[i] = data[i].apply(lambda x: np.nan if x == 0 else x)

# %% [markdown]
# # Summary of Missing Values

# %%
data.isna().sum()
# Out:
# BOROUGH                               0
# NEIGHBORHOOD                         17
# BUILDING CLASS CATEGORY            3454
# TAX CLASS AT PRESENT                143
# BLOCK                                 0
# LOT                                   0
# EASE-MENT                         27395
# BUILDING CLASS AT PRESENT           143
# ADDRESS                               0
# APARTMENT NUMBER                  14570
# ZIP CODE                              0
# RESIDENTIAL UNITS                 16372
# COMMERCIAL UNITS                  23962
# TOTAL UNITS                        9704
# LAND SQUARE FEET                  22906
# GROSS SQUARE FEET                 23069
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                         7593
# SALE DATE                             0
# dtype: int64

# %% [markdown]
# The above list shows how many values are missing in each column

# %% [markdown]
# ## Drop Columns

# %%
print("size before:", data.shape)
data.drop(columns = ["BOROUGH", "EASE-MENT", "APARTMENT NUMBER"], inplace = True)
print("size after:", data.shape)
# Out:
# size before: (27395, 21)
# size after: (27395, 18)

# %% [markdown]
# ## Drop Duplicates

# %%
print("size before:", data.shape)
data.drop_duplicates(inplace = True)
print("size after:", data.shape)
# Out:
# size before: (27395, 18)
# size after: (25790, 18)

# %% [markdown]
# ## Drop Rows with NaN

# %%
og_data = pd.DataFrame(data=data)

print("size before:", data.shape)
data.dropna(inplace = True)
print("size after:", data.shape)
# Out:
# size before: (25790, 18)
# size after: (470, 18)

# %% [markdown]
# # Outliers

# %% [markdown]
# For this data, an outlier will be defined as 2 standard deviations from the mean. Theoretically 95% of all values should be within 2 STD from the mean in any distribution.

# %%
data.describe()
# Out:
#              BLOCK          LOT      ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET   YEAR BUILT  TAX CLASS AT TIME OF SALE    SALE PRICE
# count   470.000000   470.000000    470.000000         470.000000        470.000000   470.000000        470.000000         470.000000   470.000000                 470.000000  4.700000e+02
# mean   1115.668085    43.470213  10025.927660          20.376596          2.168085    22.517021       4205.270213       21550.563830  1915.446809                   2.165957  1.040005e+07
# std     631.103400    61.664113     31.934953          46.634183          3.293633    47.435769       8037.013843       47270.568964    20.445891                   0.748923  2.878480e+07
# min      11.000000     1.000000  10001.000000           1.000000          1.000000     1.000000        469.000000        1650.000000  1877.000000                   1.000000  1.000000e+00
# 25%     494.250000    18.000000  10012.000000           4.000000          1.000000     5.000000       1875.000000        5807.750000  1900.000000                   2.000000  3.050000e+06
# 50%    1060.000000    32.000000  10020.000000           8.000000          2.000000    10.000000       2469.000000        8972.500000  1910.000000                   2.000000  5.150625e+06
# 75%    1645.000000    50.000000  10030.000000          20.000000          2.000000    23.000000       4071.500000       18087.500000  1920.000000                   2.000000  8.593184e+06
# max    2230.000000  1001.000000  10463.000000         538.000000         63.000000   550.000000     150322.000000      509090.000000  2011.000000                   4.000000  3.800000e+08

# %% [markdown]
# This table shows a description of number values (not numerical) in the data and shows some stastics. Initially we can say that BLOCK, LOT, ZIP CODE and TAX CLASS AT TIME OF SALE, cant contain outliers since they are categorical. For the rest we can check if the max and min values are within two standard deviations of the mean.
#
# <table>
#   <tr>
#     <th>Column</th>
#     <th>Accepted Range</th>
#     <th>Data Range</th>
#     <th>Contains Outliers</th>
#   </tr>
#   <tr>
#     <th>COMMERIAL UNITS</th>
#     <th>[-4.419181, 8.755351]</th>
#     <th>[1, 63]</th>
#     <th>yes</th>
#   </tr>
#   <tr>
#     <th>LAND SQUARE FEET</th>
#     <th>[-11868.757473, 20279.297899]</th>
#     <th>[469, 150322]</th>
#     <th>yes</th>
#   </tr>
#   <tr>
#     <th>GROSS SQUARE FEET</th>
#     <th>[-72990.574098, 116091.701758]</th>
#     <th>[1650, 509090]</th>
#     <th>yes</th>
#   </tr>
#   <tr>
#     <th>RESIDENTIAL UNITS</th>
#     <th>[-72.89177, 113.644962]</th>
#     <th>[1, 538]</th>
#     <th>yes</th>
#   </tr>
#    <tr>
#     <th>TOTAL UNITS</th>
#     <th>[-72.354517, 117.388559]</th>
#     <th>[1, 550]</th>
#     <th>yes</th>
#   </tr>
#   <tr>
#     <th>SALE PRICE</th>
#     <th>[-4.7169550e7, 6.7969650e7]</th>
#     <th>[1, 3.8e8]</th>
#     <th>yes</th>
#   </tr>
# </table>
#
# This means all of the columns in the table above should have a check to remove outliers

# %%
def identify_outlier(df, features):
    temp = np.zeros(df.shape[0])
    desc = df.describe()
    for i in features:
        iqr = desc[i]["75%"] - desc[i]["25%"]
        for j, x in enumerate(df[i]):
            if x < (desc[i]["25%"] - 1.5*(iqr)) or x > (desc[i]["75%"] + 1.5*(iqr)):
                temp[j] = 1
    df['outlier'] = temp
    return df

data = identify_outlier(data, ["LAND SQUARE FEET","GROSS SQUARE FEET","SALE PRICE"])
print("number of outliers identified:", data['outlier'].sum())
data = data[data.outlier == 0]
data.drop('outlier', axis = 1, inplace = True)
# Out:
# number of outliers identified: 95.0

# %%
def treat_outlier_by_zscore(df, features):
    temp = np.zeros(df.shape[0])
    desc = df.describe()
    for i in features:
        for j, x in enumerate(df[i]):
            if x < (desc[i]["mean"] - 3*desc[i]["std"]) or x > (desc[i]["mean"] + 3*desc[i]["std"]):
                temp[j] = 1
    df['outlier'] = temp
    return df

# %% [markdown]
# # Summary

# %%
data.shape
# Out:
# (375, 18)

# %% [markdown]
# The shape of the resulting data is (375, 18). This means there are 18 different columns and 375 different entries and is the end sample size

# %% [markdown]
# # Normalisation and lnprice

# %%
data["lnprice"] = np.log(data["SALE PRICE"])
data.describe()
# Out:
#              BLOCK         LOT     ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET   YEAR BUILT  TAX CLASS AT TIME OF SALE    SALE PRICE     lnprice
# count   375.000000  375.000000    375.00000         375.000000        375.000000   375.000000        375.000000         375.000000   375.000000                 375.000000  3.750000e+02  375.000000
# mean   1066.962667   41.424000  10024.97600           9.749333          1.682667    11.405333       2465.288000        9405.034667  1912.106667                   2.149333  5.100382e+06   14.933111
# std     615.180465   42.043509     33.17297           8.567511          1.025396     9.016679       1162.682965        6026.987976    14.609144                   0.762836  3.350443e+06    2.005161
# min      11.000000    1.000000  10001.00000           1.000000          1.000000     1.000000        469.000000        1650.000000  1877.000000                   1.000000  1.000000e+01    2.302585
# 25%     474.000000   17.000000  10011.00000           3.000000          1.000000     5.000000       1735.000000        5339.000000  1900.000000                   2.000000  2.842488e+06   14.860187
# 50%     998.000000   33.000000  10019.00000           7.000000          1.000000     8.000000       2320.000000        7685.000000  1910.000000                   2.000000  4.500000e+06   15.319588
# 75%    1561.000000   49.500000  10029.00000          15.000000          2.000000    16.500000       2581.500000       11044.000000  1920.000000                   2.000000  6.916875e+06   15.749472
# max    2230.000000  505.000000  10463.00000          39.000000         10.000000    42.000000       7064.000000       31500.000000  2010.000000                   4.000000  1.665000e+07   16.627921

# %%
def normalise(df, columns):
    desc = df.describe()
    for i in columns:
        print("Normalising column: "+i)
        temp = np.zeros(df.shape[0])
        for j, x in enumerate(df[i]):
            temp[j] = (x-desc[i]["min"])/(desc[i]["max"]-desc[i]["min"])
        df[i] = temp
    return df

# %%
data = normalise(data, ["COMMERCIAL UNITS","LAND SQUARE FEET","GROSS SQUARE FEET","RESIDENTIAL UNITS","SALE PRICE", "TOTAL UNITS", "lnprice"])
data.describe()
# Out:
# Normalising column: COMMERCIAL UNITS
# Normalising column: LAND SQUARE FEET
# Normalising column: GROSS SQUARE FEET
# Normalising column: RESIDENTIAL UNITS
# Normalising column: SALE PRICE
# Normalising column: TOTAL UNITS
# Normalising column: lnprice
#              BLOCK         LOT     ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET   YEAR BUILT  TAX CLASS AT TIME OF SALE  SALE PRICE     lnprice
# count   375.000000  375.000000    375.00000         375.000000        375.000000   375.000000        375.000000         375.000000   375.000000                 375.000000  375.000000  375.000000
# mean   1066.962667   41.424000  10024.97600           0.230246          0.075852     0.253789          0.302697           0.259800  1912.106667                   2.149333    0.306329    0.881691
# std     615.180465   42.043509     33.17297           0.225461          0.113933     0.219919          0.176298           0.201909    14.609144                   0.762836    0.201228    0.139973
# min      11.000000    1.000000  10001.00000           0.000000          0.000000     0.000000          0.000000           0.000000  1877.000000                   1.000000    0.000000    0.000000
# 25%     474.000000   17.000000  10011.00000           0.052632          0.000000     0.097561          0.191964           0.123585  1900.000000                   2.000000    0.170719    0.876601
# 50%     998.000000   33.000000  10019.00000           0.157895          0.000000     0.170732          0.280667           0.202178  1910.000000                   2.000000    0.270270    0.908670
# 75%    1561.000000   49.500000  10029.00000           0.368421          0.111111     0.378049          0.320318           0.314707  1920.000000                   2.000000    0.415428    0.938679
# max    2230.000000  505.000000  10463.00000           1.000000          1.000000     1.000000          1.000000           1.000000  2010.000000                   4.000000    1.000000    1.000000

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Visualise the prices across specific neighborhoods
# Scatter plots do not work with categorical variables, in this case for specific neighbourhoods. Therefore, to get a real depiction of categorical variable of a neighbourhood affecting price (numerical variable) we can use boxplots.

# %%
'''
First explore typical prices across different specific neighbourhoods.
'''

def price_neigh(df):
    unique_neigh = df["NEIGHBORHOOD"].unique() 
    fig, axs = plt.subplots(7, 5,figsize=(20, 30), gridspec_kw={'width_ratios': [2, 2, 2, 2, 2],'height_ratios': [8, 8, 8, 8, 8, 8, 8]})
    fig.suptitle('Box plot of sale prices in different neighbourhoods', fontsize=16, y=0.9)
    subr=0
    subc=0
    for un in range(0,len(unique_neigh)):
        dfN = df.loc[df["NEIGHBORHOOD"]==unique_neigh[un]]
        #df.loc[df["NEIGHBORHOOD"]==unique_neigh[un]].boxplot("lnprice","NEIGHBORHOOD", ax)
        axs[subr,subc].boxplot(dfN["GROSS SQUARE FEET"], "NEIGHBORHOOD")
        #axs[subr,subc].set_title("Box plot of sale prices in {}".format(unique_neigh[un]))
        if subc == 0:
            axs[subr,subc].set_ylabel("sale prices")
        axs[subr,subc].set_xlabel(unique_neigh[un])
        axs[subr,subc].set_aspect('auto')
        if subc==4:
            subc=0
            subr+=1
        else:
            subc+=1
    plt.show()

    
price_neigh(data)

# %% [markdown]
# Varying price quartiles and medians within different neighbourhoods suggest that the neighbourhood has an impact on overall sale price and should be considered by the model.

# %% [markdown]
# ### Visualise the prices over time

# %%
def price_time(df):
    plt.figure(figsize=(20,15))
    plt.scatter(df["SALE DATE"].values.astype('datetime64[M]'), df["SALE PRICE"], c=df["SALE PRICE"], cmap="cool")
    plt.title("prices over time (per month)")
    plt.xlabel("date of sales")
    plt.xticks(df["SALE DATE"].values.astype('datetime64[M]'))
    plt.ylabel("sale price")
    plt.show()
    
    
price_time(data)

# %% [markdown]
# Can see that prices generally lie between 0 and 0.2 over the years with some outliers from 0.2 and beyond (almost reaching 1). Issue with number of datapoints closer to end date - biasing the scatter plot results. Later prices are not congested between 0 and 0.2 and are positioned nearing higher prices than earlier dates.

# %%
def p_bc(df):
    unique_bc = df["BUILDING CLASS AT TIME OF SALE"].unique() 
    fig, axs = plt.subplots(6, 5,figsize=(20, 30), gridspec_kw={'width_ratios': [4, 4, 4, 4, 4],'height_ratios': [6, 6, 6, 6, 6, 6]})
    fig.suptitle('Box plot of sale prices in different building classes', fontsize=16, y=0.9)
    subr=0
    subc=0
    for un in range(0,len(unique_bc)):
        dfN = df.loc[df["BUILDING CLASS AT TIME OF SALE"]==unique_bc[un]]
        axs[subr,subc].boxplot(dfN["SALE PRICE"], "BUILDING CLASS AT TIME OF SALE")
        if subc == 0:
            axs[subr,subc].set_ylabel("sale prices")
        axs[subr,subc].set_xlabel(unique_bc[un])
        axs[subr,subc].set_aspect('auto')
        if subc==4:
            subc=0
            subr+=1
        else:
            subc+=1
    plt.show()
p_bc(data)

# %% [markdown]
# Variability within different values of the building class suggest that the class of the property greatly determines the sale price.

# %%
'''
Prices against year of build with colour coding of different building classes
'''
def prices_build(df):
    plt.figure(figsize=(20,15))
    groups = df.groupby('BUILDING CLASS AT TIME OF SALE')
    for name, gdf in groups:
        plt.scatter(gdf["YEAR BUILT"], gdf["SALE PRICE"], s=[5*4], label=name)
    plt.ylabel("sale price")
    plt.xlabel("year built")
    plt.suptitle("lnprice of specific year builds and their respective build classes", y=0.9)
    plt.legend()
    plt.show()
prices_build(data)

# %% [markdown]
# From this scatter plot we can conclude that the year build of the property factors greatly into the price. However, the number of data points for later years (>1960) is reduced. This may build some bias in the model predictions to favour the smaller set of data points for later years. Variability within the different classes for price output suggest that the class parameter could be considered in the final model.

# %%
def price_grossSq(df):
    plt.title("Scatter plot of prices over gross sq feet")
    plt.scatter(df["GROSS SQUARE FEET"], df["SALE PRICE"], s=2)
    plt.ylabel("price")
    plt.xlabel("GROSS SQUARE FEET")
    plt.show()
    
    
price_grossSq(data)

# %%
def price_tu(df):
    plt.title("Scatter plot of prices over total units of a property")
    plt.scatter(df["TOTAL UNITS"], df["SALE PRICE"], s=2)
    plt.ylabel("price")
    plt.xlabel("TOTAL UNITS")
    plt.show()
    
    
price_tu(data)

# %% [markdown]
# ## Scatter plot matrix of numeric variables

# %%
from pandas.plotting import scatter_matrix

def scatter_m(df, numericals):
    scatter_matrix(df[numericals], diagonal='hist', figsize=(20,14), range_padding=0.25)
    plt.title('Scatter matrix of numerical columns', fontsize=16, y=7, x=-2.5)
    plt.show()
    
numericals = ['LAND SQUARE FEET', 'GROSS SQUARE FEET', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS', 'SALE PRICE','lnprice']
scatter_m(data,numericals)

# %% [markdown]
# Collinearities:
# - Near perfect positive correlation:
#         - Residential units vs Total units
# - Very strong positive correlation:
#         - Land Square feet vs Gross square feet
#         - Land Square feet vs Residential units
#         - Land Square feet vs Total units
#         - Gross square feet vs Residential units
#         - Gross square feet vs Total units
# - Weak positive correlation:
#         - Commercial units vs Land Square feet
#         - Sale price vs land square feet
#         - Sale price vs gross square feet
#         - Sale price vs Residential units
#         - Sale price vs Commercial units
#         - Sale price vs Total units
#
# ## Add negatives after sorting lnprice - NEED TO SORT OUT LNPRICE

# %% [markdown]
# ## Correlation matrix

# %%
corr = data[numericals].corr().style.background_gradient(cmap="spring")
corr
# Out:
# <style type="text/css">
# #T_77d2e_row0_col0, #T_77d2e_row1_col1, #T_77d2e_row2_col2, #T_77d2e_row3_col3, #T_77d2e_row4_col4, #T_77d2e_row5_col5, #T_77d2e_row6_col6 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_77d2e_row0_col1 {
#   background-color: #ffe11e;
#   color: #000000;
# }
# #T_77d2e_row0_col2 {
#   background-color: #ffa857;
#   color: #000000;
# }
# #T_77d2e_row0_col3 {
#   background-color: #ff7689;
#   color: #f1f1f1;
# }
# #T_77d2e_row0_col4 {
#   background-color: #ffaf50;
#   color: #000000;
# }
# #T_77d2e_row0_col5 {
#   background-color: #ff02fd;
#   color: #f1f1f1;
# }
# #T_77d2e_row0_col6, #T_77d2e_row2_col5, #T_77d2e_row3_col5, #T_77d2e_row3_col6, #T_77d2e_row6_col0, #T_77d2e_row6_col1, #T_77d2e_row6_col2, #T_77d2e_row6_col3, #T_77d2e_row6_col4 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_77d2e_row1_col0 {
#   background-color: #ffe31c;
#   color: #000000;
# }
# #T_77d2e_row1_col2 {
#   background-color: #ffae51;
#   color: #000000;
# }
# #T_77d2e_row1_col3 {
#   background-color: #ff7887;
#   color: #f1f1f1;
# }
# #T_77d2e_row1_col4 {
#   background-color: #ffb54a;
#   color: #000000;
# }
# #T_77d2e_row1_col5 {
#   background-color: #ff0bf4;
#   color: #f1f1f1;
# }
# #T_77d2e_row1_col6 {
#   background-color: #ff0af5;
#   color: #f1f1f1;
# }
# #T_77d2e_row2_col0 {
#   background-color: #ffad52;
#   color: #000000;
# }
# #T_77d2e_row2_col1 {
#   background-color: #ffb04f;
#   color: #000000;
# }
# #T_77d2e_row2_col3 {
#   background-color: #ff57a8;
#   color: #f1f1f1;
# }
# #T_77d2e_row2_col4, #T_77d2e_row4_col2 {
#   background-color: #fffe01;
#   color: #000000;
# }
# #T_77d2e_row2_col6, #T_77d2e_row4_col6 {
#   background-color: #ff0ff0;
#   color: #f1f1f1;
# }
# #T_77d2e_row3_col0 {
#   background-color: #ff758a;
#   color: #f1f1f1;
# }
# #T_77d2e_row3_col1 {
#   background-color: #ff738c;
#   color: #f1f1f1;
# }
# #T_77d2e_row3_col2 {
#   background-color: #ff4cb3;
#   color: #f1f1f1;
# }
# #T_77d2e_row3_col4 {
#   background-color: #ff6897;
#   color: #f1f1f1;
# }
# #T_77d2e_row4_col0 {
#   background-color: #ffb34c;
#   color: #000000;
# }
# #T_77d2e_row4_col1 {
#   background-color: #ffb649;
#   color: #000000;
# }
# #T_77d2e_row4_col3 {
#   background-color: #ff718e;
#   color: #f1f1f1;
# }
# #T_77d2e_row4_col5 {
#   background-color: #ff04fb;
#   color: #f1f1f1;
# }
# #T_77d2e_row5_col0, #T_77d2e_row5_col1 {
#   background-color: #ff2ed1;
#   color: #f1f1f1;
# }
# #T_77d2e_row5_col2 {
#   background-color: #ff1ee1;
#   color: #f1f1f1;
# }
# #T_77d2e_row5_col3 {
#   background-color: #ff2dd2;
#   color: #f1f1f1;
# }
# #T_77d2e_row5_col4 {
#   background-color: #ff22dd;
#   color: #f1f1f1;
# }
# #T_77d2e_row5_col6 {
#   background-color: #ff8778;
#   color: #f1f1f1;
# }
# #T_77d2e_row6_col5 {
#   background-color: #ff6e91;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_77d2e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77d2e_level0_col0" class="col_heading level0 col0" >LAND SQUARE FEET</th>
#       <th id="T_77d2e_level0_col1" class="col_heading level0 col1" >GROSS SQUARE FEET</th>
#       <th id="T_77d2e_level0_col2" class="col_heading level0 col2" >RESIDENTIAL UNITS</th>
#       <th id="T_77d2e_level0_col3" class="col_heading level0 col3" >COMMERCIAL UNITS</th>
#       <th id="T_77d2e_level0_col4" class="col_heading level0 col4" >TOTAL UNITS</th>
#       <th id="T_77d2e_level0_col5" class="col_heading level0 col5" >SALE PRICE</th>
#       <th id="T_77d2e_level0_col6" class="col_heading level0 col6" >lnprice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77d2e_level0_row0" class="row_heading level0 row0" >LAND SQUARE FEET</th>
#       <td id="T_77d2e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_77d2e_row0_col1" class="data row0 col1" >0.893943</td>
#       <td id="T_77d2e_row0_col2" class="data row0 col2" >0.699087</td>
#       <td id="T_77d2e_row0_col3" class="data row0 col3" >0.494030</td>
#       <td id="T_77d2e_row0_col4" class="data row0 col4" >0.721626</td>
#       <td id="T_77d2e_row0_col5" class="data row0 col5" >0.232682</td>
#       <td id="T_77d2e_row0_col6" class="data row0 col6" >0.062641</td>
#     </tr>
#     <tr>
#       <th id="T_77d2e_level0_row1" class="row_heading level0 row1" >GROSS SQUARE FEET</th>
#       <td id="T_77d2e_row1_col0" class="data row1 col0" >0.893943</td>
#       <td id="T_77d2e_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_77d2e_row1_col2" class="data row1 col2" >0.720043</td>
#       <td id="T_77d2e_row1_col3" class="data row1 col3" >0.503636</td>
#       <td id="T_77d2e_row1_col4" class="data row1 col4" >0.742770</td>
#       <td id="T_77d2e_row1_col5" class="data row1 col5" >0.260210</td>
#       <td id="T_77d2e_row1_col6" class="data row1 col6" >0.098159</td>
#     </tr>
#     <tr>
#       <th id="T_77d2e_level0_row2" class="row_heading level0 row2" >RESIDENTIAL UNITS</th>
#       <td id="T_77d2e_row2_col0" class="data row2 col0" >0.699087</td>
#       <td id="T_77d2e_row2_col1" class="data row2 col1" >0.720043</td>
#       <td id="T_77d2e_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_77d2e_row2_col3" class="data row2 col3" >0.381410</td>
#       <td id="T_77d2e_row2_col4" class="data row2 col4" >0.994165</td>
#       <td id="T_77d2e_row2_col5" class="data row2 col5" >0.224860</td>
#       <td id="T_77d2e_row2_col6" class="data row2 col6" >0.118166</td>
#     </tr>
#     <tr>
#       <th id="T_77d2e_level0_row3" class="row_heading level0 row3" >COMMERCIAL UNITS</th>
#       <td id="T_77d2e_row3_col0" class="data row3 col0" >0.494030</td>
#       <td id="T_77d2e_row3_col1" class="data row3 col1" >0.503636</td>
#       <td id="T_77d2e_row3_col2" class="data row3 col2" >0.381410</td>
#       <td id="T_77d2e_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_77d2e_row3_col4" class="data row3 col4" >0.476950</td>
#       <td id="T_77d2e_row3_col5" class="data row3 col5" >0.226907</td>
#       <td id="T_77d2e_row3_col6" class="data row3 col6" >0.059920</td>
#     </tr>
#     <tr>
#       <th id="T_77d2e_level0_row4" class="row_heading level0 row4" >TOTAL UNITS</th>
#       <td id="T_77d2e_row4_col0" class="data row4 col0" >0.721626</td>
#       <td id="T_77d2e_row4_col1" class="data row4 col1" >0.742770</td>
#       <td id="T_77d2e_row4_col2" class="data row4 col2" >0.994165</td>
#       <td id="T_77d2e_row4_col3" class="data row4 col3" >0.476950</td>
#       <td id="T_77d2e_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_77d2e_row4_col5" class="data row4 col5" >0.237948</td>
#       <td id="T_77d2e_row4_col6" class="data row4 col6" >0.118016</td>
#     </tr>
#     <tr>
#       <th id="T_77d2e_level0_row5" class="row_heading level0 row5" >SALE PRICE</th>
#       <td id="T_77d2e_row5_col0" class="data row5 col0" >0.232682</td>
#       <td id="T_77d2e_row5_col1" class="data row5 col1" >0.260210</td>
#       <td id="T_77d2e_row5_col2" class="data row5 col2" >0.224860</td>
#       <td id="T_77d2e_row5_col3" class="data row5 col3" >0.226907</td>
#       <td id="T_77d2e_row5_col4" class="data row5 col4" >0.237948</td>
#       <td id="T_77d2e_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_77d2e_row5_col6" class="data row5 col6" >0.558274</td>
#     </tr>
#     <tr>
#       <th id="T_77d2e_level0_row6" class="row_heading level0 row6" >lnprice</th>
#       <td id="T_77d2e_row6_col0" class="data row6 col0" >0.062641</td>
#       <td id="T_77d2e_row6_col1" class="data row6 col1" >0.098159</td>
#       <td id="T_77d2e_row6_col2" class="data row6 col2" >0.118166</td>
#       <td id="T_77d2e_row6_col3" class="data row6 col3" >0.059920</td>
#       <td id="T_77d2e_row6_col4" class="data row6 col4" >0.118016</td>
#       <td id="T_77d2e_row6_col5" class="data row6 col5" >0.558274</td>
#       <td id="T_77d2e_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Sale price has higher correl values against other columns and should be used primarily for model outcome rather than lnprice.

# %% [markdown]
# # Choosing good predictors
#
# There are 2 ways of choosing predictors for the regression model. You can either use an estimator algorithm that fits the list of numerical columns to find which columns/features best predict the outcome. The number of features we want to select depends on us and in this scenario we want at least 3 so the model generalises well. The second method is to hand pick the predictors based on the correlation matrix and choosing the features with the highest correlation to sale price.

# %%
from sklearn import svm, feature_selection, linear_model

def first_ranked_predictors(df, numerical_features, outcome_feature):
    feature_cols = df[numerical_features].columns.values.tolist()

    XO = df[feature_cols]
    YO = df[outcome_feature]
    estimator = svm.SVR(kernel="linear")
    selector = feature_selection.RFE(estimator, n_features_to_select=3, step=3)
    selector = selector.fit(XO, YO)
    # From the ranking you can select your predictors with rank 1
    # Model 1; let us select the folowing features as predictors:
    select_features = np.array(feature_cols)[selector.ranking_ == 1].tolist()
    return select_features

select_features = first_ranked_predictors(data, ['COMMERCIAL UNITS', 'TOTAL UNITS', 'RESIDENTIAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET'], 'SALE PRICE')
print(select_features)
# Out:
# ['COMMERCIAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET']

# %% [markdown]
# # Data splitting and Model training
# sklearn's functions can be used to split the dataset into a large train set and a small test set to compare the predictions with. Since, we want to predict the house sale price we need to use a linear regression model. After, the model is trained we can find the training and test accuracy.

# %%
from sklearn.model_selection import train_test_split

def data_split_train(df, predictor_features, outcome_feature):
    X = df[predictor_features]
    Y = df[outcome_feature]
    trainX, testX, trainY, testY = train_test_split(X, Y, test_size=0.2) #, random_state=42)
    lm = linear_model.LinearRegression()
    lm.fit(trainX, trainY)
    # Inspect the calculated model equations
    print("Y-axis intercept {:6.4f}".format(lm.intercept_))
    print("Weight coefficients:")
    for feat, coef in zip(predictor_features, lm.coef_):
        print(" {:>20}: {:6.4f}".format(feat, coef))
    # The value of R^2
    print("R squared for the training data is {:4.3f}".format(lm.score(trainX, trainY)))
    print("Score against test data: {:4.3f}".format(lm.score(testX, testY)))
    return (lm, testX, testY)

sp_lm, sp_testX, sp_testY = data_split_train(data, ['COMMERCIAL UNITS', 'TOTAL UNITS', 'GROSS SQUARE FEET'], 'SALE PRICE')
# Out:
# Y-axis intercept 0.2349
# Weight coefficients:
#      COMMERCIAL UNITS: 0.2438
#           TOTAL UNITS: 0.0949
#     GROSS SQUARE FEET: 0.1379
# R squared for the training data is 0.106
# Score against test data: -0.049

# %% [markdown]
# # Histogram of residuals
# Residuals are the difference in the actual value and predicted value to find out how far off the model was.

# %%
def hist_res(tModel, testX, testY):
    prediction = tModel.predict(testX)
    residuals = (testY - prediction)

    plt.figure(figsize=(12, 8))
    plt.title('Histogram of residuals', fontsize=14)
    plt.hist(residuals, color='blue', bins=50)
    plt.ylabel('Frequency')
    plt.grid()
    plt.show()
    return
hist_res(sp_lm, sp_testX, sp_testY)

# %% [markdown]
# # Cross validation

# %%
from sklearn.model_selection import cross_val_score, KFold

def cv(df, tModel, pred_features, outcome):
    crossvalidation = KFold(10, shuffle=True)
    X = df[pred_features]
    Y = df[outcome]
    scores = cross_val_score(tModel, X, Y, cv=crossvalidation) # 5 K-folds is the default value
    print("Cross validation scores: {}".format(scores))
    print("Cross validation mean scores: {}".format(np.mean(scores)))
cv(data, sp_lm, ['COMMERCIAL UNITS', 'LAND SQUARE FEET', 'GROSS SQUARE FEET'], 'SALE PRICE')
# Out:
# Cross validation scores: [ 0.05898274  0.00166842  0.03526966 -0.00782539  0.08790244  0.0101154
#  -0.00197159  0.07726192  0.07163925  0.0311686 ]
# Cross validation mean scores: 0.036421143712622894

# %% [markdown]
# # PART 2
#
# ## With a focus on cleaning the Part 1 dataset differently

# %%
valid_sp_df = pd.DataFrame(og_data[og_data['SALE PRICE'].notna()])


print("After removing rows with null sale price values")
print(valid_sp_df.shape)
print(valid_sp_df.isna().sum())


valid_lasqft_df = valid_sp_df[valid_sp_df['LAND SQUARE FEET'].notna()]

valid_grsqft_df = pd.DataFrame(valid_lasqft_df[valid_lasqft_df['GROSS SQUARE FEET'].notna()])

print("After removing rows with null land square feet values")
print(valid_lasqft_df.shape)
print(valid_lasqft_df.isna().sum())

print("After removing rows with null gross square feet values")
print(valid_grsqft_df.shape)
print(valid_grsqft_df.isna().sum())
# Out:
# After removing rows with null sale price values
# (18928, 18)
# NEIGHBORHOOD                         17
# BUILDING CLASS CATEGORY            1145
# TAX CLASS AT PRESENT                116
# BLOCK                                 0
# LOT                                   0
# BUILDING CLASS AT PRESENT           116
# ADDRESS                               0
# ZIP CODE                              0
# RESIDENTIAL UNITS                 11487
# COMMERCIAL UNITS                  17287
# TOTAL UNITS                        8807
# LAND SQUARE FEET                  16616
# GROSS SQUARE FEET                 16690
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                            0
# SALE DATE                             0
# dtype: int64
# After removing rows with null land square feet values
# (2312, 18)
# NEIGHBORHOOD                         0
# BUILDING CLASS CATEGORY              0
# TAX CLASS AT PRESENT                 0
# BLOCK                                0
# LOT                                  0
# BUILDING CLASS AT PRESENT            0
# ADDRESS                              0
# ZIP CODE                             0
# RESIDENTIAL UNITS                 1091
# COMMERCIAL UNITS                   828
# TOTAL UNITS                         77
# LAND SQUARE FEET                     0
# GROSS SQUARE FEET                   80
# YEAR BUILT                           0
# TAX CLASS AT TIME OF SALE            0
# BUILDING CLASS AT TIME OF SALE       0
# SALE PRICE                           0
# SALE DATE                            0
# dtype: int64
# After removing rows with null gross square feet values
# (2232, 18)
# NEIGHBORHOOD                         0
# BUILDING CLASS CATEGORY              0
# TAX CLASS AT PRESENT                 0
# BLOCK                                0
# LOT                                  0
# BUILDING CLASS AT PRESENT            0
# ADDRESS                              0
# ZIP CODE                             0
# RESIDENTIAL UNITS                 1012
# COMMERCIAL UNITS                   753
# TOTAL UNITS                          3
# LAND SQUARE FEET                     0
# GROSS SQUARE FEET                    0
# YEAR BUILT                           0
# TAX CLASS AT TIME OF SALE            0
# BUILDING CLASS AT TIME OF SALE       0
# SALE PRICE                           0
# SALE DATE                            0
# dtype: int64

# %%
valid_grsqft_df['RESIDENTIAL UNITS'] = valid_grsqft_df['RESIDENTIAL UNITS'].replace(to_replace = np.nan,  value = 0)
valid_grsqft_df['COMMERCIAL UNITS'] = valid_grsqft_df['COMMERCIAL UNITS'].replace(to_replace = np.nan,  value = 0)
valid_grsqft_df['TOTAL UNITS'] = valid_grsqft_df['TOTAL UNITS'].replace(to_replace = np.nan,  value = 0)

# %%
valid_class_cat = valid_sp_df.dropna(subset=['NEIGHBORHOOD','TAX CLASS AT PRESENT', 'BUILDING CLASS AT PRESENT', 'BUILDING CLASS CATEGORY'])

# %%
valid_class_cat.isna().sum()
# Out:
# NEIGHBORHOOD                          0
# BUILDING CLASS CATEGORY               0
# TAX CLASS AT PRESENT                  0
# BLOCK                                 0
# LOT                                   0
# BUILDING CLASS AT PRESENT             0
# ADDRESS                               0
# ZIP CODE                              0
# RESIDENTIAL UNITS                 10228
# COMMERCIAL UNITS                  16027
# TOTAL UNITS                        8691
# LAND SQUARE FEET                  15356
# GROSS SQUARE FEET                 15430
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                            0
# SALE DATE                             0
# dtype: int64

# %%
print(numericals)
# Out:
# ['LAND SQUARE FEET', 'GROSS SQUARE FEET', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS', 'SALE PRICE', 'lnprice']

# %%
def imputate_gross_land():
    dfLand = og_data[og_data['LAND SQUARE FEET'].notna()]
    dfGross = og_data[og_data['GROSS SQUARE FEET'].notna()]
    landI = {}
    grossI = {}
    groupsLand = dfLand.groupby(['BUILDING CLASS AT TIME OF SALE','NEIGHBORHOOD']).mean()
    groupsGross = dfGross.groupby(['BUILDING CLASS AT TIME OF SALE','NEIGHBORHOOD']).mean()

    for n in og_data["NEIGHBORHOOD"].unique():
        for cl in og_data["BUILDING CLASS AT TIME OF SALE"].unique():
            try:
                grossI[n+":"+cl] = groupsGross.loc[(groupsGross.index.get_level_values('NEIGHBORHOOD')==n) & (groupsGross.index.get_level_values("BUILDING CLASS AT TIME OF SALE")==cl), "GROSS SQUARE FEET"].values[0]
                landI[n+":"+cl] = groupsLand.loc[(groupsLand.index.get_level_values('NEIGHBORHOOD')==n) & (groupsLand.index.get_level_values("BUILDING CLASS AT TIME OF SALE")==cl), "LAND SQUARE FEET"].values[0]
            except:#empty value
                pass
            
    tempDf = valid_sp_df.copy()
    
    for k,v in landI.items():
        keyS = k.split(":")
        tempDf["LAND SQUARE FEET"].loc[(tempDf["NEIGHBORHOOD"]==keyS[0])&\
            (tempDf["BUILDING CLASS AT TIME OF SALE"]==keyS[1])] = tempDf["LAND SQUARE FEET"].loc[(tempDf["NEIGHBORHOOD"]==keyS[0])&\
            (tempDf["BUILDING CLASS AT TIME OF SALE"]==keyS[1])].replace(to_replace = np.nan,  value = landI[keyS[0]+":"+keyS[1]])
        
    for k,v in grossI.items():
        keyS = k.split(":")
        tempDf["GROSS SQUARE FEET"].loc[(tempDf["NEIGHBORHOOD"]==keyS[0])&\
            (tempDf["BUILDING CLASS AT TIME OF SALE"]==keyS[1])] = tempDf["GROSS SQUARE FEET"].loc[(tempDf["NEIGHBORHOOD"]==keyS[0])&\
            (tempDf["BUILDING CLASS AT TIME OF SALE"]==keyS[1])].replace(to_replace = np.nan,  value = grossI[keyS[0]+":"+keyS[1]])
        
    return tempDf

imputed_data = imputate_gross_land()
imputed_data.isna().sum()
# Out:
# C:\Users\George\AppData\Local\Temp\ipykernel_16092\2501698202.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   groupsLand = dfLand.groupby(['BUILDING CLASS AT TIME OF SALE','NEIGHBORHOOD']).mean()
# C:\Users\George\AppData\Local\Temp\ipykernel_16092\2501698202.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   groupsGross = dfGross.groupby(['BUILDING CLASS AT TIME OF SALE','NEIGHBORHOOD']).mean()
# C:\Users\George\AppData\Local\Temp\ipykernel_16092\2501698202.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempDf["LAND SQUARE FEET"].loc[(tempDf["NEIGHBORHOOD"]==keyS[0])&\
# C:\Users\George\AppData\Local\Temp\ipykernel_16092\2501698202.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempDf["GROSS SQUARE FEET"].loc[(tempDf["NEIGHBORHOOD"]==keyS[0])&\
# NEIGHBORHOOD                         17
# BUILDING CLASS CATEGORY            1145
# TAX CLASS AT PRESENT                116
# BLOCK                                 0
# LOT                                   0
# BUILDING CLASS AT PRESENT           116
# ADDRESS                               0
# ZIP CODE                              0
# RESIDENTIAL UNITS                 11487
# COMMERCIAL UNITS                  17287
# TOTAL UNITS                        8807
# LAND SQUARE FEET                  12448
# GROSS SQUARE FEET                 12415
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                            0
# SALE DATE                             0
# dtype: int64

# %%
valid_grsqft_df.isna().sum()
# Out:
# NEIGHBORHOOD                      0
# BUILDING CLASS CATEGORY           0
# TAX CLASS AT PRESENT              0
# BLOCK                             0
# LOT                               0
# BUILDING CLASS AT PRESENT         0
# ADDRESS                           0
# ZIP CODE                          0
# RESIDENTIAL UNITS                 0
# COMMERCIAL UNITS                  0
# TOTAL UNITS                       0
# LAND SQUARE FEET                  0
# GROSS SQUARE FEET                 0
# YEAR BUILT                        0
# TAX CLASS AT TIME OF SALE         0
# BUILDING CLASS AT TIME OF SALE    0
# SALE PRICE                        0
# SALE DATE                         0
# dtype: int64

# %%
valid_grsqft_df.shape
# Out:
# (2232, 18)

# %%
valid_grsqft_df["lnprice"] = pd.DataFrame(np.log(valid_grsqft_df["SALE PRICE"]))

# %%
valid_grsqft_df.describe()
# Out:
#              BLOCK          LOT      ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET   YEAR BUILT  TAX CLASS AT TIME OF SALE    SALE PRICE      lnprice
# count  2232.000000  2232.000000   2232.000000        2232.000000       2232.000000  2232.000000       2232.000000        2232.000000  2232.000000                2232.000000  2.232000e+03  2232.000000
# mean   1214.444444    48.492384  10025.397401           9.758961          2.083333    11.836470       5963.900538       54965.280466  1944.948477                   2.829749  1.008254e+07    13.751327
# std     533.654143    84.960317     28.316174          27.446736          6.322801    28.012158       8793.566208       74804.703895    45.781452                   1.171395  4.246882e+07     2.853660
# min      11.000000     1.000000  10001.000000           0.000000          0.000000     0.000000        469.000000         999.000000  1800.000000                   1.000000  1.000000e+00     0.000000
# 25%    1009.000000    26.000000  10019.000000           0.000000          0.000000     2.000000       2018.000000        5662.250000  1910.000000                   2.000000  8.832650e+04    11.388792
# 50%    1009.000000    37.000000  10019.000000           1.000000          2.000000     3.000000       4600.000000       17077.500000  1920.000000                   2.000000  2.200000e+06    14.603968
# 75%    1661.250000    45.000000  10028.000000          10.000000          2.000000    11.000000       7532.000000      112850.000000  2007.000000                   4.000000  6.256250e+06    15.649090
# max    2246.000000  1502.000000  10463.000000         538.000000        150.000000   550.000000     213650.000000      940000.000000  2013.000000                   4.000000  1.100000e+09    20.818576

# %%
valid_grsqft_df = identify_outlier(valid_grsqft_df, ["SALE PRICE", "lnprice", "LAND SQUARE FEET", "GROSS SQUARE FEET"])
print(display(valid_grsqft_df.head(10)))
print("number of outliers identified:", valid_grsqft_df['outlier'].sum())
valid_grsqft_df = valid_grsqft_df[valid_grsqft_df.outlier == 0]
valid_grsqft_df.drop('outlier', axis = 1, inplace = True)
# Out:
#     NEIGHBORHOOD     BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT               ADDRESS  ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE BUILDING CLASS AT TIME OF SALE  SALE PRICE  SALE DATE    lnprice  outlier
# 18  ALPHABETCITY          03THREEFAMILYHOMES                    1    377   66                        C0      243EAST7THSTREET     10009                3.0               0.0          3.0            2381.0             3084.0        1899                          1                             C0   3150000.0 2013-03-06  14.962913      0.0
# 21  ALPHABETCITY  07RENTALS-WALKUPAPARTMENTS                    2    375   62                        C4      715EAST5THSTREET     10009               20.0               0.0         20.0            2426.0             9345.0        1900                          2                             C4   3650000.0 2012-09-06  15.110238      0.0
# 22  ALPHABETCITY  07RENTALS-WALKUPAPARTMENTS                    2    376   30                        C4  274EASTSEVENTHSTREET     10009               13.0               0.0         13.0            2726.0            13002.0        1910                          2                             C4    895250.0 2012-10-25  13.704858      0.0
# 24  ALPHABETCITY  07RENTALS-WALKUPAPARTMENTS                   2B    385    1                        C7             17AVENUEB     10009                7.0               1.0          8.0            2093.0             5852.0        1997                          2                             C7       283.0 2013-04-18   5.645447      0.0
# 25  ALPHABETCITY  07RENTALS-WALKUPAPARTMENTS                    2    391   55                        C4      309EAST8THSTREET     10009               17.0               0.0         17.0            2164.0             9071.0        1900                          2                             C4   3500000.0 2012-10-16  15.068274      0.0
# 26  ALPHABETCITY  07RENTALS-WALKUPAPARTMENTS                    2    397   33                        C7             14AVENUEB     10009               25.0               2.0         27.0            3574.0            18212.0        1925                          2                             C7  13185684.0 2013-01-31  16.394642      0.0
# 30  ALPHABETCITY  07RENTALS-WALKUPAPARTMENTS                    2    398   53                        C7      170EAST2NDSTREET     10009               36.0               3.0         39.0            4452.0            17664.0        1900                          2                             C7   3810602.0 2012-10-26  15.153298      0.0
# 31  ALPHABETCITY  07RENTALS-WALKUPAPARTMENTS                   2B    400   56                        C4      203EAST4THSTREET     10009               10.0               1.0         10.0            2404.0             6975.0        1900                          2                             C4   7333333.0 2013-04-09  15.807941      0.0
# 32  ALPHABETCITY  07RENTALS-WALKUPAPARTMENTS                   2B    400   57                        C4      201EAST4THSTREET     10009                9.0               1.0          9.0            2404.0             6875.0        1900                          2                             C4   7333333.0 2013-04-09  15.807941      0.0
# 33  ALPHABETCITY  07RENTALS-WALKUPAPARTMENTS                   2B    400   58                        C4      199EAST4THSTREET     10009                9.0               1.0         10.0            2404.0             7110.0        1900                          2                             C4   7333333.0 2013-04-09  15.807941      0.0
# None
# number of outliers identified: 294.0

# %%
valid_grsqft_df.shape
# Out:
# (1938, 19)

# %%
valid_grsqft_df.describe()
# Out:
#              BLOCK          LOT      ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET   YEAR BUILT  TAX CLASS AT TIME OF SALE    SALE PRICE      lnprice
# count  1938.000000  1938.000000   1938.000000        1938.000000        1938.00000  1938.000000       1938.000000        1938.000000  1938.000000                1938.000000  1.938000e+03  1938.000000
# mean   1231.640351    46.449432  10025.655831           7.312693           1.44324     8.750774       4762.994324       48086.784314  1946.949948                   2.796182  2.994304e+06    13.563589
# std     529.283937    67.061024     29.198990          13.223321           2.74038    13.209652       3022.515326       49851.971484    47.107212                   1.176805  3.542832e+06     2.084434
# min      11.000000     1.000000  10001.000000           0.000000           0.00000     0.000000        469.000000         999.000000  1800.000000                   1.000000  1.830000e+02     5.209486
# 25%    1009.000000    29.000000  10019.000000           0.000000           0.00000     2.000000       1998.500000        5272.000000  1910.000000                   2.000000  8.349500e+04    11.332542
# 50%    1009.000000    37.000000  10019.000000           1.000000           2.00000     2.000000       3871.000000       14000.000000  1920.000000                   2.000000  1.555000e+06    14.256981
# 75%    1688.000000    44.000000  10029.000000           9.000000           2.00000    10.000000       7532.000000      112850.000000  2007.000000                   4.000000  4.900000e+06    15.404746
# max    2246.000000  1502.000000  10463.000000         180.000000          60.00000   181.000000      15800.000000      155975.000000  2010.000000                   4.000000  1.550000e+07    16.556351

# %%
normalised_df = normalise(valid_grsqft_df, ["COMMERCIAL UNITS","GROSS SQUARE FEET","LAND SQUARE FEET","RESIDENTIAL UNITS","SALE PRICE", "TOTAL UNITS", "lnprice"])
normalised_df.describe()
# Out:
# Normalising column: COMMERCIAL UNITS
# Normalising column: GROSS SQUARE FEET
# Normalising column: LAND SQUARE FEET
# Normalising column: RESIDENTIAL UNITS
# Normalising column: SALE PRICE
# Normalising column: TOTAL UNITS
# Normalising column: lnprice
#              BLOCK          LOT      ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET   YEAR BUILT  TAX CLASS AT TIME OF SALE   SALE PRICE      lnprice
# count  1938.000000  1938.000000   1938.000000        1938.000000       1938.000000  1938.000000       1938.000000        1938.000000  1938.000000                1938.000000  1938.000000  1938.000000
# mean   1231.640351    46.449432  10025.655831           0.040626          0.024054     0.048347          0.280086           0.303839  1946.949948                   2.796182     0.193171     0.736248
# std     529.283937    67.061024     29.198990           0.073463          0.045673     0.072982          0.197151           0.321675    47.107212                   1.176805     0.228573     0.183701
# min      11.000000     1.000000  10001.000000           0.000000          0.000000     0.000000          0.000000           0.000000  1800.000000                   1.000000     0.000000     0.000000
# 25%    1009.000000    29.000000  10019.000000           0.000000          0.000000     0.011050          0.099765           0.027572  1910.000000                   2.000000     0.005375     0.539625
# 50%    1009.000000    37.000000  10019.000000           0.005556          0.033333     0.011050          0.221903           0.083890  1920.000000                   2.000000     0.100312     0.797356
# 75%    1688.000000    44.000000  10029.000000           0.050000          0.033333     0.055249          0.460701           0.721731  2007.000000                   4.000000     0.316121     0.898509
# max    2246.000000  1502.000000  10463.000000           1.000000          1.000000     1.000000          1.000000           1.000000  2010.000000                   4.000000     1.000000     1.000000

# %%
normalised_df.isna().sum()
# Out:
# NEIGHBORHOOD                      0
# BUILDING CLASS CATEGORY           0
# TAX CLASS AT PRESENT              0
# BLOCK                             0
# LOT                               0
# BUILDING CLASS AT PRESENT         0
# ADDRESS                           0
# ZIP CODE                          0
# RESIDENTIAL UNITS                 0
# COMMERCIAL UNITS                  0
# TOTAL UNITS                       0
# LAND SQUARE FEET                  0
# GROSS SQUARE FEET                 0
# YEAR BUILT                        0
# TAX CLASS AT TIME OF SALE         0
# BUILDING CLASS AT TIME OF SALE    0
# SALE PRICE                        0
# SALE DATE                         0
# lnprice                           0
# dtype: int64

# %%
#cleaned_data.hist(bins=60, figsize=(20, 10))

# %%
normalised_df.shape
# Out:
# (1938, 19)

# %%
corr = normalised_df[numericals].corr().style.background_gradient(cmap="spring")
corr
# Out:
# <style type="text/css">
# #T_ca2ef_row0_col0, #T_ca2ef_row1_col1, #T_ca2ef_row2_col2, #T_ca2ef_row3_col3, #T_ca2ef_row4_col4, #T_ca2ef_row5_col5, #T_ca2ef_row6_col6 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_ca2ef_row0_col1 {
#   background-color: #ffe51a;
#   color: #000000;
# }
# #T_ca2ef_row0_col2, #T_ca2ef_row4_col1 {
#   background-color: #ff58a7;
#   color: #f1f1f1;
# }
# #T_ca2ef_row0_col3 {
#   background-color: #ff4bb4;
#   color: #f1f1f1;
# }
# #T_ca2ef_row0_col4 {
#   background-color: #ff5ba4;
#   color: #f1f1f1;
# }
# #T_ca2ef_row0_col5 {
#   background-color: #ff2cd3;
#   color: #f1f1f1;
# }
# #T_ca2ef_row0_col6 {
#   background-color: #ff28d7;
#   color: #f1f1f1;
# }
# #T_ca2ef_row1_col0 {
#   background-color: #ffe01f;
#   color: #000000;
# }
# #T_ca2ef_row1_col2, #T_ca2ef_row1_col4, #T_ca2ef_row1_col5, #T_ca2ef_row1_col6, #T_ca2ef_row2_col3, #T_ca2ef_row6_col0, #T_ca2ef_row6_col1, #T_ca2ef_row6_col3 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_ca2ef_row1_col3 {
#   background-color: #ff4ab5;
#   color: #f1f1f1;
# }
# #T_ca2ef_row2_col0 {
#   background-color: #ff7887;
#   color: #f1f1f1;
# }
# #T_ca2ef_row2_col1 {
#   background-color: #ff51ae;
#   color: #f1f1f1;
# }
# #T_ca2ef_row2_col4, #T_ca2ef_row4_col2 {
#   background-color: #fffb04;
#   color: #000000;
# }
# #T_ca2ef_row2_col5, #T_ca2ef_row4_col5 {
#   background-color: #ff9b64;
#   color: #000000;
# }
# #T_ca2ef_row2_col6 {
#   background-color: #ffaf50;
#   color: #000000;
# }
# #T_ca2ef_row3_col0 {
#   background-color: #ff7e81;
#   color: #f1f1f1;
# }
# #T_ca2ef_row3_col1 {
#   background-color: #ff926d;
#   color: #000000;
# }
# #T_ca2ef_row3_col2 {
#   background-color: #ff1ce3;
#   color: #f1f1f1;
# }
# #T_ca2ef_row3_col4 {
#   background-color: #ff3fc0;
#   color: #f1f1f1;
# }
# #T_ca2ef_row3_col5 {
#   background-color: #ff59a6;
#   color: #f1f1f1;
# }
# #T_ca2ef_row3_col6 {
#   background-color: #ff649b;
#   color: #f1f1f1;
# }
# #T_ca2ef_row4_col0 {
#   background-color: #ff7f80;
#   color: #f1f1f1;
# }
# #T_ca2ef_row4_col3 {
#   background-color: #ff30cf;
#   color: #f1f1f1;
# }
# #T_ca2ef_row4_col6 {
#   background-color: #ffac53;
#   color: #000000;
# }
# #T_ca2ef_row5_col0 {
#   background-color: #ff29d6;
#   color: #f1f1f1;
# }
# #T_ca2ef_row5_col1 {
#   background-color: #ff26d9;
#   color: #f1f1f1;
# }
# #T_ca2ef_row5_col2 {
#   background-color: #ff827d;
#   color: #f1f1f1;
# }
# #T_ca2ef_row5_col3 {
#   background-color: #ff15ea;
#   color: #f1f1f1;
# }
# #T_ca2ef_row5_col4 {
#   background-color: #ff7d82;
#   color: #f1f1f1;
# }
# #T_ca2ef_row5_col6 {
#   background-color: #ffe718;
#   color: #000000;
# }
# #T_ca2ef_row6_col2 {
#   background-color: #ff8976;
#   color: #f1f1f1;
# }
# #T_ca2ef_row6_col4 {
#   background-color: #ff807f;
#   color: #f1f1f1;
# }
# #T_ca2ef_row6_col5 {
#   background-color: #ffe21d;
#   color: #000000;
# }
# </style>
# <table id="T_ca2ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca2ef_level0_col0" class="col_heading level0 col0" >LAND SQUARE FEET</th>
#       <th id="T_ca2ef_level0_col1" class="col_heading level0 col1" >GROSS SQUARE FEET</th>
#       <th id="T_ca2ef_level0_col2" class="col_heading level0 col2" >RESIDENTIAL UNITS</th>
#       <th id="T_ca2ef_level0_col3" class="col_heading level0 col3" >COMMERCIAL UNITS</th>
#       <th id="T_ca2ef_level0_col4" class="col_heading level0 col4" >TOTAL UNITS</th>
#       <th id="T_ca2ef_level0_col5" class="col_heading level0 col5" >SALE PRICE</th>
#       <th id="T_ca2ef_level0_col6" class="col_heading level0 col6" >lnprice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca2ef_level0_row0" class="row_heading level0 row0" >LAND SQUARE FEET</th>
#       <td id="T_ca2ef_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ca2ef_row0_col1" class="data row0 col1" >0.808868</td>
#       <td id="T_ca2ef_row0_col2" class="data row0 col2" >0.182858</td>
#       <td id="T_ca2ef_row0_col3" class="data row0 col3" >0.217741</td>
#       <td id="T_ca2ef_row0_col4" class="data row0 col4" >0.228575</td>
#       <td id="T_ca2ef_row0_col5" class="data row0 col5" >-0.290374</td>
#       <td id="T_ca2ef_row0_col6" class="data row0 col6" >-0.541446</td>
#     </tr>
#     <tr>
#       <th id="T_ca2ef_level0_row1" class="row_heading level0 row1" >GROSS SQUARE FEET</th>
#       <td id="T_ca2ef_row1_col0" class="data row1 col0" >0.808868</td>
#       <td id="T_ca2ef_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ca2ef_row1_col2" class="data row1 col2" >-0.245509</td>
#       <td id="T_ca2ef_row1_col3" class="data row1 col3" >0.214750</td>
#       <td id="T_ca2ef_row1_col4" class="data row1 col4" >-0.200888</td>
#       <td id="T_ca2ef_row1_col5" class="data row1 col5" >-0.558309</td>
#       <td id="T_ca2ef_row1_col6" class="data row1 col6" >-0.830540</td>
#     </tr>
#     <tr>
#       <th id="T_ca2ef_level0_row2" class="row_heading level0 row2" >RESIDENTIAL UNITS</th>
#       <td id="T_ca2ef_row2_col0" class="data row2 col0" >0.182858</td>
#       <td id="T_ca2ef_row2_col1" class="data row2 col1" >-0.245509</td>
#       <td id="T_ca2ef_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ca2ef_row2_col3" class="data row2 col3" >-0.108612</td>
#       <td id="T_ca2ef_row2_col4" class="data row2 col4" >0.978483</td>
#       <td id="T_ca2ef_row2_col5" class="data row2 col5" >0.390233</td>
#       <td id="T_ca2ef_row2_col6" class="data row2 col6" >0.423112</td>
#     </tr>
#     <tr>
#       <th id="T_ca2ef_level0_row3" class="row_heading level0 row3" >COMMERCIAL UNITS</th>
#       <td id="T_ca2ef_row3_col0" class="data row3 col0" >0.217741</td>
#       <td id="T_ca2ef_row3_col1" class="data row3 col1" >0.214750</td>
#       <td id="T_ca2ef_row3_col2" class="data row3 col2" >-0.108612</td>
#       <td id="T_ca2ef_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_ca2ef_row3_col4" class="data row3 col4" >0.098734</td>
#       <td id="T_ca2ef_row3_col5" class="data row3 col5" >-0.014237</td>
#       <td id="T_ca2ef_row3_col6" class="data row3 col6" >-0.109480</td>
#     </tr>
#     <tr>
#       <th id="T_ca2ef_level0_row4" class="row_heading level0 row4" >TOTAL UNITS</th>
#       <td id="T_ca2ef_row4_col0" class="data row4 col0" >0.228575</td>
#       <td id="T_ca2ef_row4_col1" class="data row4 col1" >-0.200888</td>
#       <td id="T_ca2ef_row4_col2" class="data row4 col2" >0.978483</td>
#       <td id="T_ca2ef_row4_col3" class="data row4 col3" >0.098734</td>
#       <td id="T_ca2ef_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_ca2ef_row4_col5" class="data row4 col5" >0.387263</td>
#       <td id="T_ca2ef_row4_col6" class="data row4 col6" >0.400445</td>
#     </tr>
#     <tr>
#       <th id="T_ca2ef_level0_row5" class="row_heading level0 row5" >SALE PRICE</th>
#       <td id="T_ca2ef_row5_col0" class="data row5 col0" >-0.290374</td>
#       <td id="T_ca2ef_row5_col1" class="data row5 col1" >-0.558309</td>
#       <td id="T_ca2ef_row5_col2" class="data row5 col2" >0.390233</td>
#       <td id="T_ca2ef_row5_col3" class="data row5 col3" >-0.014237</td>
#       <td id="T_ca2ef_row5_col4" class="data row5 col4" >0.387263</td>
#       <td id="T_ca2ef_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_ca2ef_row5_col6" class="data row5 col6" >0.822089</td>
#     </tr>
#     <tr>
#       <th id="T_ca2ef_level0_row6" class="row_heading level0 row6" >lnprice</th>
#       <td id="T_ca2ef_row6_col0" class="data row6 col0" >-0.541446</td>
#       <td id="T_ca2ef_row6_col1" class="data row6 col1" >-0.830540</td>
#       <td id="T_ca2ef_row6_col2" class="data row6 col2" >0.423112</td>
#       <td id="T_ca2ef_row6_col3" class="data row6 col3" >-0.109480</td>
#       <td id="T_ca2ef_row6_col4" class="data row6 col4" >0.400445</td>
#       <td id="T_ca2ef_row6_col5" class="data row6 col5" >0.822089</td>
#       <td id="T_ca2ef_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
scatter_m(normalised_df,numericals)

# %%
print(numericals)

scatter_m(normalised_df,numericals)
# Out:
# ['LAND SQUARE FEET', 'GROSS SQUARE FEET', 'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS', 'SALE PRICE', 'lnprice']

# %%
normalised_df[numericals].corr().style.background_gradient(cmap="spring")
# Out:
# <style type="text/css">
# #T_f3b85_row0_col0, #T_f3b85_row1_col1, #T_f3b85_row2_col2, #T_f3b85_row3_col3, #T_f3b85_row4_col4, #T_f3b85_row5_col5, #T_f3b85_row6_col6 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_f3b85_row0_col1 {
#   background-color: #ffe51a;
#   color: #000000;
# }
# #T_f3b85_row0_col2, #T_f3b85_row4_col1 {
#   background-color: #ff58a7;
#   color: #f1f1f1;
# }
# #T_f3b85_row0_col3 {
#   background-color: #ff4bb4;
#   color: #f1f1f1;
# }
# #T_f3b85_row0_col4 {
#   background-color: #ff5ba4;
#   color: #f1f1f1;
# }
# #T_f3b85_row0_col5 {
#   background-color: #ff2cd3;
#   color: #f1f1f1;
# }
# #T_f3b85_row0_col6 {
#   background-color: #ff28d7;
#   color: #f1f1f1;
# }
# #T_f3b85_row1_col0 {
#   background-color: #ffe01f;
#   color: #000000;
# }
# #T_f3b85_row1_col2, #T_f3b85_row1_col4, #T_f3b85_row1_col5, #T_f3b85_row1_col6, #T_f3b85_row2_col3, #T_f3b85_row6_col0, #T_f3b85_row6_col1, #T_f3b85_row6_col3 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_f3b85_row1_col3 {
#   background-color: #ff4ab5;
#   color: #f1f1f1;
# }
# #T_f3b85_row2_col0 {
#   background-color: #ff7887;
#   color: #f1f1f1;
# }
# #T_f3b85_row2_col1 {
#   background-color: #ff51ae;
#   color: #f1f1f1;
# }
# #T_f3b85_row2_col4, #T_f3b85_row4_col2 {
#   background-color: #fffb04;
#   color: #000000;
# }
# #T_f3b85_row2_col5, #T_f3b85_row4_col5 {
#   background-color: #ff9b64;
#   color: #000000;
# }
# #T_f3b85_row2_col6 {
#   background-color: #ffaf50;
#   color: #000000;
# }
# #T_f3b85_row3_col0 {
#   background-color: #ff7e81;
#   color: #f1f1f1;
# }
# #T_f3b85_row3_col1 {
#   background-color: #ff926d;
#   color: #000000;
# }
# #T_f3b85_row3_col2 {
#   background-color: #ff1ce3;
#   color: #f1f1f1;
# }
# #T_f3b85_row3_col4 {
#   background-color: #ff3fc0;
#   color: #f1f1f1;
# }
# #T_f3b85_row3_col5 {
#   background-color: #ff59a6;
#   color: #f1f1f1;
# }
# #T_f3b85_row3_col6 {
#   background-color: #ff649b;
#   color: #f1f1f1;
# }
# #T_f3b85_row4_col0 {
#   background-color: #ff7f80;
#   color: #f1f1f1;
# }
# #T_f3b85_row4_col3 {
#   background-color: #ff30cf;
#   color: #f1f1f1;
# }
# #T_f3b85_row4_col6 {
#   background-color: #ffac53;
#   color: #000000;
# }
# #T_f3b85_row5_col0 {
#   background-color: #ff29d6;
#   color: #f1f1f1;
# }
# #T_f3b85_row5_col1 {
#   background-color: #ff26d9;
#   color: #f1f1f1;
# }
# #T_f3b85_row5_col2 {
#   background-color: #ff827d;
#   color: #f1f1f1;
# }
# #T_f3b85_row5_col3 {
#   background-color: #ff15ea;
#   color: #f1f1f1;
# }
# #T_f3b85_row5_col4 {
#   background-color: #ff7d82;
#   color: #f1f1f1;
# }
# #T_f3b85_row5_col6 {
#   background-color: #ffe718;
#   color: #000000;
# }
# #T_f3b85_row6_col2 {
#   background-color: #ff8976;
#   color: #f1f1f1;
# }
# #T_f3b85_row6_col4 {
#   background-color: #ff807f;
#   color: #f1f1f1;
# }
# #T_f3b85_row6_col5 {
#   background-color: #ffe21d;
#   color: #000000;
# }
# </style>
# <table id="T_f3b85">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3b85_level0_col0" class="col_heading level0 col0" >LAND SQUARE FEET</th>
#       <th id="T_f3b85_level0_col1" class="col_heading level0 col1" >GROSS SQUARE FEET</th>
#       <th id="T_f3b85_level0_col2" class="col_heading level0 col2" >RESIDENTIAL UNITS</th>
#       <th id="T_f3b85_level0_col3" class="col_heading level0 col3" >COMMERCIAL UNITS</th>
#       <th id="T_f3b85_level0_col4" class="col_heading level0 col4" >TOTAL UNITS</th>
#       <th id="T_f3b85_level0_col5" class="col_heading level0 col5" >SALE PRICE</th>
#       <th id="T_f3b85_level0_col6" class="col_heading level0 col6" >lnprice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3b85_level0_row0" class="row_heading level0 row0" >LAND SQUARE FEET</th>
#       <td id="T_f3b85_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f3b85_row0_col1" class="data row0 col1" >0.808868</td>
#       <td id="T_f3b85_row0_col2" class="data row0 col2" >0.182858</td>
#       <td id="T_f3b85_row0_col3" class="data row0 col3" >0.217741</td>
#       <td id="T_f3b85_row0_col4" class="data row0 col4" >0.228575</td>
#       <td id="T_f3b85_row0_col5" class="data row0 col5" >-0.290374</td>
#       <td id="T_f3b85_row0_col6" class="data row0 col6" >-0.541446</td>
#     </tr>
#     <tr>
#       <th id="T_f3b85_level0_row1" class="row_heading level0 row1" >GROSS SQUARE FEET</th>
#       <td id="T_f3b85_row1_col0" class="data row1 col0" >0.808868</td>
#       <td id="T_f3b85_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f3b85_row1_col2" class="data row1 col2" >-0.245509</td>
#       <td id="T_f3b85_row1_col3" class="data row1 col3" >0.214750</td>
#       <td id="T_f3b85_row1_col4" class="data row1 col4" >-0.200888</td>
#       <td id="T_f3b85_row1_col5" class="data row1 col5" >-0.558309</td>
#       <td id="T_f3b85_row1_col6" class="data row1 col6" >-0.830540</td>
#     </tr>
#     <tr>
#       <th id="T_f3b85_level0_row2" class="row_heading level0 row2" >RESIDENTIAL UNITS</th>
#       <td id="T_f3b85_row2_col0" class="data row2 col0" >0.182858</td>
#       <td id="T_f3b85_row2_col1" class="data row2 col1" >-0.245509</td>
#       <td id="T_f3b85_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_f3b85_row2_col3" class="data row2 col3" >-0.108612</td>
#       <td id="T_f3b85_row2_col4" class="data row2 col4" >0.978483</td>
#       <td id="T_f3b85_row2_col5" class="data row2 col5" >0.390233</td>
#       <td id="T_f3b85_row2_col6" class="data row2 col6" >0.423112</td>
#     </tr>
#     <tr>
#       <th id="T_f3b85_level0_row3" class="row_heading level0 row3" >COMMERCIAL UNITS</th>
#       <td id="T_f3b85_row3_col0" class="data row3 col0" >0.217741</td>
#       <td id="T_f3b85_row3_col1" class="data row3 col1" >0.214750</td>
#       <td id="T_f3b85_row3_col2" class="data row3 col2" >-0.108612</td>
#       <td id="T_f3b85_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_f3b85_row3_col4" class="data row3 col4" >0.098734</td>
#       <td id="T_f3b85_row3_col5" class="data row3 col5" >-0.014237</td>
#       <td id="T_f3b85_row3_col6" class="data row3 col6" >-0.109480</td>
#     </tr>
#     <tr>
#       <th id="T_f3b85_level0_row4" class="row_heading level0 row4" >TOTAL UNITS</th>
#       <td id="T_f3b85_row4_col0" class="data row4 col0" >0.228575</td>
#       <td id="T_f3b85_row4_col1" class="data row4 col1" >-0.200888</td>
#       <td id="T_f3b85_row4_col2" class="data row4 col2" >0.978483</td>
#       <td id="T_f3b85_row4_col3" class="data row4 col3" >0.098734</td>
#       <td id="T_f3b85_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_f3b85_row4_col5" class="data row4 col5" >0.387263</td>
#       <td id="T_f3b85_row4_col6" class="data row4 col6" >0.400445</td>
#     </tr>
#     <tr>
#       <th id="T_f3b85_level0_row5" class="row_heading level0 row5" >SALE PRICE</th>
#       <td id="T_f3b85_row5_col0" class="data row5 col0" >-0.290374</td>
#       <td id="T_f3b85_row5_col1" class="data row5 col1" >-0.558309</td>
#       <td id="T_f3b85_row5_col2" class="data row5 col2" >0.390233</td>
#       <td id="T_f3b85_row5_col3" class="data row5 col3" >-0.014237</td>
#       <td id="T_f3b85_row5_col4" class="data row5 col4" >0.387263</td>
#       <td id="T_f3b85_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_f3b85_row5_col6" class="data row5 col6" >0.822089</td>
#     </tr>
#     <tr>
#       <th id="T_f3b85_level0_row6" class="row_heading level0 row6" >lnprice</th>
#       <td id="T_f3b85_row6_col0" class="data row6 col0" >-0.541446</td>
#       <td id="T_f3b85_row6_col1" class="data row6 col1" >-0.830540</td>
#       <td id="T_f3b85_row6_col2" class="data row6 col2" >0.423112</td>
#       <td id="T_f3b85_row6_col3" class="data row6 col3" >-0.109480</td>
#       <td id="T_f3b85_row6_col4" class="data row6 col4" >0.400445</td>
#       <td id="T_f3b85_row6_col5" class="data row6 col5" >0.822089</td>
#       <td id="T_f3b85_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
cleanedDf_predictors = first_ranked_predictors(valid_grsqft_df, ['COMMERCIAL UNITS', 'TOTAL UNITS', 'RESIDENTIAL UNITS', 'TAX CLASS AT TIME OF SALE', 'SALE PRICE', 'lnprice'], 'LAND SQUARE FEET')
print(cleanedDf_predictors)
# Out:
# ['TOTAL UNITS', 'RESIDENTIAL UNITS', 'lnprice']

# %%
gross_lm, gross_testX, gross_testY = data_split_train(normalised_df, ['TOTAL UNITS', 'lnprice'], 'GROSS SQUARE FEET')
# Out:
# Y-axis intercept 1.4070
# Weight coefficients:
#           TOTAL UNITS: 0.6730
#               lnprice: -1.5413
# R squared for the training data is 0.698
# Score against test data: 0.763

# %%
cv(normalised_df, gross_lm, ['TAX CLASS AT TIME OF SALE','lnprice'], 'GROSS SQUARE FEET')
# Out:
# Cross validation scores: [0.76337558 0.82412079 0.75427714 0.7906225  0.81383221 0.786622
#  0.67096577 0.80894507 0.79577553 0.78371578]
# Cross validation mean scores: 0.7792252380356964

# %%
normalised_df.dtypes
# Out:
# NEIGHBORHOOD                              object
# BUILDING CLASS CATEGORY                   object
# TAX CLASS AT PRESENT                      object
# BLOCK                                      int64
# LOT                                        int64
# BUILDING CLASS AT PRESENT                 object
# ADDRESS                                   object
# ZIP CODE                                   int64
# RESIDENTIAL UNITS                        float64
# COMMERCIAL UNITS                         float64
# TOTAL UNITS                              float64
# LAND SQUARE FEET                         float64
# GROSS SQUARE FEET                        float64
# YEAR BUILT                                 int64
# TAX CLASS AT TIME OF SALE                  int64
# BUILDING CLASS AT TIME OF SALE            object
# SALE PRICE                               float64
# SALE DATE                         datetime64[ns]
# lnprice                                  float64
# dtype: object

# %% [markdown]
# # PART 2 upgrades

# %%
from sklearn.ensemble import RandomForestRegressor

def rf_train(df, predictor_features, outcome_feature):
    X = df[predictor_features]
    Y = df[outcome_feature]
    trainX, testX, trainY, testY = train_test_split(X, Y, test_size=0.2) #, random_state=42)
    rf = RandomForestRegressor(n_estimators = 300, max_features = 'sqrt', max_depth = 5, random_state = 18).fit(trainX, trainY)
    print("R squared for the training data is {:4.3f}".format(rf.score(trainX, trainY)))
    print("Score against test data: {:4.3f}".format(rf.score(testX, testY)))
    return rf

# %%
gross_rf = rf_train(normalised_df, ['TOTAL UNITS', 'lnprice'], 'GROSS SQUARE FEET')
# Out:
# R squared for the training data is 0.979
# Score against test data: 0.966

# %%
cv(normalised_df, gross_rf, ['TOTAL UNITS', 'lnprice'], 'GROSS SQUARE FEET')
# Out:
# Cross validation scores: [0.94060839 0.98531259 0.9530452  0.98046101 0.97232796 0.95715186
#  0.97150233 0.99261872 0.93536476 0.96042014]
# Cross validation mean scores: 0.9648812955102425

# %%
land_rf = rf_train(normalised_df, ['TOTAL UNITS', 'lnprice', 'GROSS SQUARE FEET'], 'LAND SQUARE FEET')
# Out:
# R squared for the training data is 0.914
# Score against test data: 0.954

# %%
cv(normalised_df, land_rf, ['TOTAL UNITS', 'lnprice', 'GROSS SQUARE FEET'], 'LAND SQUARE FEET')
# Out:
# Cross validation scores: [0.9251342  0.94996692 0.79465946 0.92128654 0.92872082 0.87037829
#  0.89239976 0.93277875 0.82588864 0.8761497 ]
# Cross validation mean scores: 0.891736308204883

# %%
valid_sp_df.isna().sum()
# Out:
# NEIGHBORHOOD                         17
# BUILDING CLASS CATEGORY            1145
# TAX CLASS AT PRESENT                116
# BLOCK                                 0
# LOT                                   0
# BUILDING CLASS AT PRESENT           116
# ADDRESS                               0
# ZIP CODE                              0
# RESIDENTIAL UNITS                 11487
# COMMERCIAL UNITS                  17287
# TOTAL UNITS                        8807
# LAND SQUARE FEET                  16616
# GROSS SQUARE FEET                 16690
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                            0
# SALE DATE                             0
# dtype: int64

# %%
valid_sp_df['lnprice'] = np.log(valid_sp_df['SALE PRICE'])

no_outliers = identify_outlier(valid_sp_df, ["SALE PRICE", 'lnprice'])
print("number of outliers identified:", no_outliers['outlier'].sum())
no_outliers = no_outliers[no_outliers.outlier == 0]
no_outliers.drop('outlier', axis = 1, inplace = True)

missing_gross = pd.DataFrame(no_outliers[no_outliers['GROSS SQUARE FEET'].isna()])

missing_gross['RESIDENTIAL UNITS'] = missing_gross['RESIDENTIAL UNITS'].replace(to_replace = np.nan,  value = 0)
missing_gross['COMMERCIAL UNITS'] = missing_gross['COMMERCIAL UNITS'].replace(to_replace = np.nan,  value = 0)
missing_gross['TOTAL UNITS'] = missing_gross['TOTAL UNITS'].replace(to_replace = np.nan,  value = 0)

missing_gross = normalise(missing_gross, ["COMMERCIAL UNITS","GROSS SQUARE FEET","LAND SQUARE FEET","RESIDENTIAL UNITS","SALE PRICE", "TOTAL UNITS", "lnprice"])

missing_X = missing_gross[['TOTAL UNITS', 'lnprice']]
missing_X
# Out:
# number of outliers identified: 3517.0
# Normalising column: COMMERCIAL UNITS
# Normalising column: GROSS SQUARE FEET
# C:\Users\George\AppData\Local\Temp\ipykernel_16092\2780634361.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_outliers.drop('outlier', axis = 1, inplace = True)
# Normalising column: LAND SQUARE FEET
# Normalising column: RESIDENTIAL UNITS
# Normalising column: SALE PRICE
# Normalising column: TOTAL UNITS
# Normalising column: lnprice
#        TOTAL UNITS   lnprice
# 0         0.000000  0.884756
# 1         0.000000  0.816574
# 2         0.000000  0.714432
# 3         0.000000  0.773211
# 4         0.000000  0.815853
# ...            ...       ...
# 27367     0.111111  0.575386
# 27368     0.111111  0.545848
# 27387     0.000000  0.612005
# 27389     0.000000  0.304135
# 27391     0.000000  0.534324
#
# [14284 rows x 2 columns]

# %%
missing_gross.describe()
# Out:
#               BLOCK           LOT      ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET    YEAR BUILT  TAX CLASS AT TIME OF SALE    SALE PRICE       lnprice
# count  14284.000000  14284.000000  14284.000000       14284.000000      14284.000000  14284.000000         42.000000                0.0  14284.000000               14284.000000  14284.000000  14284.000000
# mean    1120.473887    699.994679  10031.176561           0.043460          0.007841      0.046696          0.159877                NaN   1689.605923                   2.059717      0.272964      0.644221
# std      506.907608    864.676312     38.977630           0.054796          0.088204      0.055411          0.186205                NaN    666.133332                   0.343783      0.212554      0.172875
# min       11.000000      1.000000  10001.000000           0.000000          0.000000      0.000000          0.000000                NaN      0.000000                   1.000000      0.000000      0.000000
# 25%      803.000000     26.000000  10013.000000           0.000000          0.000000      0.000000          0.065445                NaN   1914.000000                   2.000000      0.121580      0.529551
# 50%     1171.000000    410.500000  10022.000000           0.000000          0.000000      0.000000          0.105968                NaN   1939.000000                   2.000000      0.199910      0.636138
# 75%     1451.000000   1153.000000  10028.000000           0.111111          0.000000      0.111111          0.160937                NaN   1965.000000                   2.000000      0.364964      0.769845
# max     2250.000000   9046.000000  10282.000000           1.000000          1.000000      1.000000          1.000000                NaN   2013.000000                   4.000000      1.000000      1.000000

# %%
pred_gross = gross_rf.predict(missing_X)
missing_gross['GROSS SQUARE FEET'] = pred_gross

# %%
missing_gross.describe()
# Out:
#               BLOCK           LOT      ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET    YEAR BUILT  TAX CLASS AT TIME OF SALE    SALE PRICE       lnprice
# count  14284.000000  14284.000000  14284.000000       14284.000000      14284.000000  14284.000000         42.000000       14284.000000  14284.000000               14284.000000  14284.000000  14284.000000
# mean    1120.473887    699.994679  10031.176561           0.043460          0.007841      0.046696          0.159877           0.152801   1689.605923                   2.059717      0.272964      0.644221
# std      506.907608    864.676312     38.977630           0.054796          0.088204      0.055411          0.186205           0.097432    666.133332                   0.343783      0.212554      0.172875
# min       11.000000      1.000000  10001.000000           0.000000          0.000000      0.000000          0.000000           0.039867      0.000000                   1.000000      0.000000      0.000000
# 25%      803.000000     26.000000  10013.000000           0.000000          0.000000      0.000000          0.065445           0.064400   1914.000000                   2.000000      0.121580      0.529551
# 50%     1171.000000    410.500000  10022.000000           0.000000          0.000000      0.000000          0.105968           0.125685   1939.000000                   2.000000      0.199910      0.636138
# 75%     1451.000000   1153.000000  10028.000000           0.111111          0.000000      0.111111          0.160937           0.264070   1965.000000                   2.000000      0.364964      0.769845
# max     2250.000000   9046.000000  10282.000000           1.000000          1.000000      1.000000          1.000000           0.441489   2013.000000                   4.000000      1.000000      1.000000

# %%
valid_gross = pd.DataFrame(no_outliers[no_outliers['GROSS SQUARE FEET'].notna()])

valid_gross['RESIDENTIAL UNITS'] = valid_gross['RESIDENTIAL UNITS'].replace(to_replace = np.nan,  value = 0)
valid_gross['COMMERCIAL UNITS'] = valid_gross['COMMERCIAL UNITS'].replace(to_replace = np.nan,  value = 0)
valid_gross['TOTAL UNITS'] = valid_gross['TOTAL UNITS'].replace(to_replace = np.nan,  value = 0)

valid_gross = normalise(valid_gross, ["COMMERCIAL UNITS","GROSS SQUARE FEET","LAND SQUARE FEET","RESIDENTIAL UNITS","SALE PRICE", "TOTAL UNITS", "lnprice"])

valid_gross.isna().sum()
# Out:
# Normalising column: COMMERCIAL UNITS
# Normalising column: GROSS SQUARE FEET
# Normalising column: LAND SQUARE FEET
# Normalising column: RESIDENTIAL UNITS
# Normalising column: SALE PRICE
# Normalising column: TOTAL UNITS
# Normalising column: lnprice
# NEIGHBORHOOD                      0
# BUILDING CLASS CATEGORY           0
# TAX CLASS AT PRESENT              0
# BLOCK                             0
# LOT                               0
# BUILDING CLASS AT PRESENT         0
# ADDRESS                           0
# ZIP CODE                          0
# RESIDENTIAL UNITS                 0
# COMMERCIAL UNITS                  0
# TOTAL UNITS                       0
# LAND SQUARE FEET                  0
# GROSS SQUARE FEET                 0
# YEAR BUILT                        0
# TAX CLASS AT TIME OF SALE         0
# BUILDING CLASS AT TIME OF SALE    0
# SALE PRICE                        0
# SALE DATE                         0
# lnprice                           0
# dtype: int64

# %%
valid_gross.describe()
# Out:
#              BLOCK          LOT      ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET   YEAR BUILT  TAX CLASS AT TIME OF SALE   SALE PRICE      lnprice
# count  1127.000000  1127.000000   1127.000000        1127.000000       1127.000000  1127.000000       1127.000000        1127.000000  1127.000000                1127.000000  1127.000000  1127.000000
# mean   1304.400177    48.272405  10025.637090           0.015562          0.024460     0.019957          0.112575           0.179751  1959.566105                   3.004437     0.257811     0.452544
# std     506.813239    69.362598     32.172804           0.044988          0.050169     0.044967          0.082457           0.158944    48.930777                   1.178922     0.320504     0.368357
# min      64.000000     1.000000  10001.000000           0.000000          0.000000     0.000000          0.000000           0.000000  1890.000000                   1.000000     0.000000     0.000000
# 25%    1009.000000    37.000000  10019.000000           0.000000          0.000000     0.005988          0.034928           0.011592  1910.000000                   2.000000     0.008408     0.109578
# 50%    1009.000000    37.000000  10019.000000           0.000000          0.033333     0.005988          0.164137           0.249583  2007.000000                   4.000000     0.053641     0.367405
# 75%    1829.000000    38.500000  10029.000000           0.014970          0.033333     0.017964          0.164137           0.333342  2007.000000                   4.000000     0.461501     0.823023
# max    2238.000000  1103.000000  10463.000000           1.000000          1.000000     1.000000          1.000000           1.000000  2013.000000                   4.000000     1.000000     1.000000

# %%
treated_gross = pd.concat([missing_gross,valid_gross])
treated_gross.isna().sum()
# Out:
# NEIGHBORHOOD                         15
# BUILDING CLASS CATEGORY             242
# TAX CLASS AT PRESENT                 96
# BLOCK                                 0
# LOT                                   0
# BUILDING CLASS AT PRESENT            96
# ADDRESS                               0
# ZIP CODE                              0
# RESIDENTIAL UNITS                     0
# COMMERCIAL UNITS                      0
# TOTAL UNITS                           0
# LAND SQUARE FEET                  14242
# GROSS SQUARE FEET                     0
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                            0
# SALE DATE                             0
# lnprice                               0
# dtype: int64

# %%
treated_gross.describe()
# Out:
#               BLOCK           LOT      ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET    YEAR BUILT  TAX CLASS AT TIME OF SALE    SALE PRICE       lnprice
# count  15411.000000  15411.000000  15411.000000       15411.000000      15411.000000  15411.000000       1169.000000       15411.000000  15411.000000               15411.000000  15411.000000  15411.000000
# mean    1133.924340    652.334501  10030.771462           0.041420          0.009056      0.044740          0.114275           0.154772   1709.347998                   2.128804      0.271856      0.630203
# std      509.141222    849.781303     38.546847           0.054622          0.086103      0.055155          0.088597           0.103411    645.287956                   0.521151      0.222253      0.200263
# min       11.000000      1.000000  10001.000000           0.000000          0.000000      0.000000          0.000000           0.000000      0.000000                   1.000000      0.000000      0.000000
# 25%      838.000000     27.000000  10014.000000           0.000000          0.000000      0.000000          0.035579           0.064307   1913.000000                   2.000000      0.114586      0.517173
# 50%     1170.000000     69.000000  10022.000000           0.000000          0.000000      0.000000          0.164137           0.125969   1939.000000                   2.000000      0.197113      0.633061
# 75%     1459.000000   1133.000000  10028.000000           0.111111          0.000000      0.111111          0.164137           0.287229   1971.000000                   2.000000      0.370559      0.773272
# max     2250.000000   9046.000000  10463.000000           1.000000          1.000000      1.000000          1.000000           1.000000   2013.000000                   4.000000      1.000000      1.000000

# %%
missing_land = pd.DataFrame(treated_gross[treated_gross['LAND SQUARE FEET'].isna()])

# %%
missing_land.isna().sum()
# Out:
# NEIGHBORHOOD                         15
# BUILDING CLASS CATEGORY             242
# TAX CLASS AT PRESENT                 96
# BLOCK                                 0
# LOT                                   0
# BUILDING CLASS AT PRESENT            96
# ADDRESS                               0
# ZIP CODE                              0
# RESIDENTIAL UNITS                     0
# COMMERCIAL UNITS                      0
# TOTAL UNITS                           0
# LAND SQUARE FEET                  14242
# GROSS SQUARE FEET                     0
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                            0
# SALE DATE                             0
# lnprice                               0
# dtype: int64

# %%
missing_land.describe()
# Out:
#               BLOCK           LOT      ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET    YEAR BUILT  TAX CLASS AT TIME OF SALE    SALE PRICE       lnprice
# count  14242.000000  14242.000000  14242.000000       14242.000000      14242.000000  14242.000000               0.0       14242.000000  14242.000000               14242.000000  14242.000000  14242.000000
# mean    1118.779174    701.854374  10031.176801           0.043518          0.007794      0.046755               NaN           0.152800   1694.454501                   2.053995      0.272854      0.644195
# std      505.807144    865.246901     39.023579           0.054238          0.087941      0.054856               NaN           0.097370    660.905786                   0.327719      0.212366      0.172779
# min       11.000000      1.000000  10001.000000           0.000000          0.000000      0.000000               NaN           0.039867      0.000000                   1.000000      0.000000      0.000000
# 25%      802.000000     26.000000  10013.000000           0.000000          0.000000      0.000000               NaN           0.064400   1915.000000                   2.000000      0.121580      0.529551
# 50%     1171.000000    489.000000  10022.000000           0.000000          0.000000      0.000000               NaN           0.125685   1939.000000                   2.000000      0.199910      0.636138
# 75%     1450.000000   1154.000000  10028.000000           0.111111          0.000000      0.111111               NaN           0.264070   1965.000000                   2.000000      0.364790      0.769738
# max     2250.000000   9046.000000  10282.000000           0.111111          1.000000      0.111111               NaN           0.297807   2013.000000                   4.000000      1.000000      1.000000

# %%
missing_land_X = missing_land[['TOTAL UNITS', 'lnprice', 'GROSS SQUARE FEET']]
pred_land = land_rf.predict(missing_land_X)
missing_land['LAND SQUARE FEET'] = pred_land

# %%
missing_land.isna().sum()
# Out:
# NEIGHBORHOOD                       15
# BUILDING CLASS CATEGORY           242
# TAX CLASS AT PRESENT               96
# BLOCK                               0
# LOT                                 0
# BUILDING CLASS AT PRESENT          96
# ADDRESS                             0
# ZIP CODE                            0
# RESIDENTIAL UNITS                   0
# COMMERCIAL UNITS                    0
# TOTAL UNITS                         0
# LAND SQUARE FEET                    0
# GROSS SQUARE FEET                   0
# YEAR BUILT                          0
# TAX CLASS AT TIME OF SALE           0
# BUILDING CLASS AT TIME OF SALE      0
# SALE PRICE                          0
# SALE DATE                           0
# lnprice                             0
# dtype: int64

# %%
missing_land.describe()
# Out:
#               BLOCK           LOT      ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET    YEAR BUILT  TAX CLASS AT TIME OF SALE    SALE PRICE       lnprice
# count  14242.000000  14242.000000  14242.000000       14242.000000      14242.000000  14242.000000      14242.000000       14242.000000  14242.000000               14242.000000  14242.000000  14242.000000
# mean    1118.779174    701.854374  10031.176801           0.043518          0.007794      0.046755          0.279722           0.152800   1694.454501                   2.053995      0.272854      0.644195
# std      505.807144    865.246901     39.023579           0.054238          0.087941      0.054856          0.128941           0.097370    660.905786                   0.327719      0.212366      0.172779
# min       11.000000      1.000000  10001.000000           0.000000          0.000000      0.000000          0.123283           0.039867      0.000000                   1.000000      0.000000      0.000000
# 25%      802.000000     26.000000  10013.000000           0.000000          0.000000      0.000000          0.152039           0.064400   1915.000000                   2.000000      0.121580      0.529551
# 50%     1171.000000    489.000000  10022.000000           0.000000          0.000000      0.000000          0.254085           0.125685   1939.000000                   2.000000      0.199910      0.636138
# 75%     1450.000000   1154.000000  10028.000000           0.111111          0.000000      0.111111          0.427955           0.264070   1965.000000                   2.000000      0.364790      0.769738
# max     2250.000000   9046.000000  10282.000000           0.111111          1.000000      0.111111          0.467297           0.297807   2013.000000                   4.000000      1.000000      1.000000

# %%
valid_land = treated_gross[treated_gross['LAND SQUARE FEET'].notna()]

# %%
valid_land.describe()
# Out:
#              BLOCK          LOT      ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET   YEAR BUILT  TAX CLASS AT TIME OF SALE   SALE PRICE      lnprice
# count  1169.000000  1169.000000   1169.000000        1169.000000       1169.000000  1169.000000       1169.000000        1169.000000  1169.000000                1169.000000  1169.000000  1169.000000
# mean   1318.438837    49.030796  10025.833191           0.015859          0.024437     0.020190          0.114275           0.178790  1890.796407                   3.040205     0.259700     0.459739
# std     513.647692    71.845075     31.777863           0.052814          0.057116     0.052842          0.088597           0.157699   363.823992                   1.172279     0.318857     0.365621
# min      64.000000     1.000000  10001.000000           0.000000          0.000000     0.000000          0.000000           0.000000     0.000000                   1.000000     0.000000     0.000000
# 25%    1009.000000    37.000000  10019.000000           0.000000          0.000000     0.005988          0.035579           0.011972  1910.000000                   2.000000     0.008700     0.112597
# 50%    1009.000000    37.000000  10019.000000           0.000000          0.033333     0.005988          0.164137           0.209183  1941.000000                   4.000000     0.083814     0.453254
# 75%    1843.000000    40.000000  10029.000000           0.011976          0.033333     0.014970          0.164137           0.333342  2007.000000                   4.000000     0.461501     0.823023
# max    2238.000000  1103.000000  10463.000000           1.000000          1.000000     1.000000          1.000000           1.000000  2013.000000                   4.000000     1.000000     1.000000

# %%
treated_land = pd.concat([missing_land,valid_land])
treated_land.isna().sum()
# Out:
# NEIGHBORHOOD                       15
# BUILDING CLASS CATEGORY           242
# TAX CLASS AT PRESENT               96
# BLOCK                               0
# LOT                                 0
# BUILDING CLASS AT PRESENT          96
# ADDRESS                             0
# ZIP CODE                            0
# RESIDENTIAL UNITS                   0
# COMMERCIAL UNITS                    0
# TOTAL UNITS                         0
# LAND SQUARE FEET                    0
# GROSS SQUARE FEET                   0
# YEAR BUILT                          0
# TAX CLASS AT TIME OF SALE           0
# BUILDING CLASS AT TIME OF SALE      0
# SALE PRICE                          0
# SALE DATE                           0
# lnprice                             0
# dtype: int64

# %%
treated_data = treated_land
treated_data.shape
# Out:
# (15411, 19)

# %%
treated_data.describe()
# Out:
#               BLOCK           LOT      ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET    YEAR BUILT  TAX CLASS AT TIME OF SALE    SALE PRICE       lnprice
# count  15411.000000  15411.000000  15411.000000       15411.000000      15411.000000  15411.000000      15411.000000       15411.000000  15411.000000               15411.000000  15411.000000  15411.000000
# mean    1133.924340    652.334501  10030.771462           0.041420          0.009056      0.044740          0.267172           0.154772   1709.347998                   2.128804      0.271856      0.630203
# std      509.141222    849.781303     38.546847           0.054622          0.086103      0.055155          0.133710           0.103411    645.287956                   0.521151      0.222253      0.200263
# min       11.000000      1.000000  10001.000000           0.000000          0.000000      0.000000          0.000000           0.000000      0.000000                   1.000000      0.000000      0.000000
# 25%      838.000000     27.000000  10014.000000           0.000000          0.000000      0.000000          0.151264           0.064307   1913.000000                   2.000000      0.114586      0.517173
# 50%     1170.000000     69.000000  10022.000000           0.000000          0.000000      0.000000          0.240468           0.125969   1939.000000                   2.000000      0.197113      0.633061
# 75%     1459.000000   1133.000000  10028.000000           0.111111          0.000000      0.111111          0.424278           0.287229   1971.000000                   2.000000      0.370559      0.773272
# max     2250.000000   9046.000000  10463.000000           1.000000          1.000000      1.000000          1.000000           1.000000   2013.000000                   4.000000      1.000000      1.000000

# %%
treated_corr = treated_data[numericals].corr().style.background_gradient(cmap="spring")
treated_corr
# Out:
# <style type="text/css">
# #T_26e84_row0_col0, #T_26e84_row1_col1, #T_26e84_row2_col2, #T_26e84_row3_col3, #T_26e84_row4_col4, #T_26e84_row5_col5, #T_26e84_row6_col6 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_26e84_row0_col1 {
#   background-color: #ffe916;
#   color: #000000;
# }
# #T_26e84_row0_col2 {
#   background-color: #ff07f8;
#   color: #f1f1f1;
# }
# #T_26e84_row0_col3 {
#   background-color: #ff04fb;
#   color: #f1f1f1;
# }
# #T_26e84_row0_col4 {
#   background-color: #ff05fa;
#   color: #f1f1f1;
# }
# #T_26e84_row0_col5 {
#   background-color: #ff0ef1;
#   color: #f1f1f1;
# }
# #T_26e84_row0_col6 {
#   background-color: #ff21de;
#   color: #f1f1f1;
# }
# #T_26e84_row1_col0 {
#   background-color: #ffe718;
#   color: #000000;
# }
# #T_26e84_row1_col2, #T_26e84_row1_col4, #T_26e84_row1_col5, #T_26e84_row1_col6, #T_26e84_row2_col3, #T_26e84_row5_col0, #T_26e84_row6_col1 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_26e84_row1_col3 {
#   background-color: #ff0cf3;
#   color: #f1f1f1;
# }
# #T_26e84_row2_col0 {
#   background-color: #ff27d8;
#   color: #f1f1f1;
# }
# #T_26e84_row2_col1 {
#   background-color: #ff34cb;
#   color: #f1f1f1;
# }
# #T_26e84_row2_col4, #T_26e84_row4_col2 {
#   background-color: #fff50a;
#   color: #000000;
# }
# #T_26e84_row2_col5 {
#   background-color: #ff8c73;
#   color: #000000;
# }
# #T_26e84_row2_col6 {
#   background-color: #ff9768;
#   color: #000000;
# }
# #T_26e84_row3_col0 {
#   background-color: #ff4eb1;
#   color: #f1f1f1;
# }
# #T_26e84_row3_col1 {
#   background-color: #ff629d;
#   color: #f1f1f1;
# }
# #T_26e84_row3_col2 {
#   background-color: #ff30cf;
#   color: #f1f1f1;
# }
# #T_26e84_row3_col4 {
#   background-color: #ff53ac;
#   color: #f1f1f1;
# }
# #T_26e84_row3_col5, #T_26e84_row3_col6 {
#   background-color: #ff6699;
#   color: #f1f1f1;
# }
# #T_26e84_row4_col0 {
#   background-color: #ff23dc;
#   color: #f1f1f1;
# }
# #T_26e84_row4_col1 {
#   background-color: #ff31ce;
#   color: #f1f1f1;
# }
# #T_26e84_row4_col3 {
#   background-color: #ff29d6;
#   color: #f1f1f1;
# }
# #T_26e84_row4_col5 {
#   background-color: #ff8a75;
#   color: #f1f1f1;
# }
# #T_26e84_row4_col6 {
#   background-color: #ff926d;
#   color: #000000;
# }
# #T_26e84_row5_col1 {
#   background-color: #ff08f7;
#   color: #f1f1f1;
# }
# #T_26e84_row5_col2 {
#   background-color: #ff738c;
#   color: #f1f1f1;
# }
# #T_26e84_row5_col3 {
#   background-color: #ff19e6;
#   color: #f1f1f1;
# }
# #T_26e84_row5_col4 {
#   background-color: #ff728d;
#   color: #f1f1f1;
# }
# #T_26e84_row5_col6, #T_26e84_row6_col5 {
#   background-color: #ffed12;
#   color: #000000;
# }
# #T_26e84_row6_col0 {
#   background-color: #ff0df2;
#   color: #f1f1f1;
# }
# #T_26e84_row6_col2 {
#   background-color: #ff7c83;
#   color: #f1f1f1;
# }
# #T_26e84_row6_col3 {
#   background-color: #ff11ee;
#   color: #f1f1f1;
# }
# #T_26e84_row6_col4 {
#   background-color: #ff7788;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_26e84">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26e84_level0_col0" class="col_heading level0 col0" >LAND SQUARE FEET</th>
#       <th id="T_26e84_level0_col1" class="col_heading level0 col1" >GROSS SQUARE FEET</th>
#       <th id="T_26e84_level0_col2" class="col_heading level0 col2" >RESIDENTIAL UNITS</th>
#       <th id="T_26e84_level0_col3" class="col_heading level0 col3" >COMMERCIAL UNITS</th>
#       <th id="T_26e84_level0_col4" class="col_heading level0 col4" >TOTAL UNITS</th>
#       <th id="T_26e84_level0_col5" class="col_heading level0 col5" >SALE PRICE</th>
#       <th id="T_26e84_level0_col6" class="col_heading level0 col6" >lnprice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26e84_level0_row0" class="row_heading level0 row0" >LAND SQUARE FEET</th>
#       <td id="T_26e84_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_26e84_row0_col1" class="data row0 col1" >0.855320</td>
#       <td id="T_26e84_row0_col2" class="data row0 col2" >-0.289986</td>
#       <td id="T_26e84_row0_col3" class="data row0 col3" >-0.059080</td>
#       <td id="T_26e84_row0_col4" class="data row0 col4" >-0.314837</td>
#       <td id="T_26e84_row0_col5" class="data row0 col5" >-0.528620</td>
#       <td id="T_26e84_row0_col6" class="data row0 col6" >-0.450692</td>
#     </tr>
#     <tr>
#       <th id="T_26e84_level0_row1" class="row_heading level0 row1" >GROSS SQUARE FEET</th>
#       <td id="T_26e84_row1_col0" class="data row1 col0" >0.855320</td>
#       <td id="T_26e84_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_26e84_row1_col2" class="data row1 col2" >-0.329896</td>
#       <td id="T_26e84_row1_col3" class="data row1 col3" >-0.025880</td>
#       <td id="T_26e84_row1_col4" class="data row1 col4" >-0.345113</td>
#       <td id="T_26e84_row1_col5" class="data row1 col5" >-0.617865</td>
#       <td id="T_26e84_row1_col6" class="data row1 col6" >-0.670269</td>
#     </tr>
#     <tr>
#       <th id="T_26e84_level0_row2" class="row_heading level0 row2" >RESIDENTIAL UNITS</th>
#       <td id="T_26e84_row2_col0" class="data row2 col0" >-0.289986</td>
#       <td id="T_26e84_row2_col1" class="data row2 col1" >-0.329896</td>
#       <td id="T_26e84_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_26e84_row2_col3" class="data row2 col3" >-0.077439</td>
#       <td id="T_26e84_row2_col4" class="data row2 col4" >0.945345</td>
#       <td id="T_26e84_row2_col5" class="data row2 col5" >0.270009</td>
#       <td id="T_26e84_row2_col6" class="data row2 col6" >0.316334</td>
#     </tr>
#     <tr>
#       <th id="T_26e84_level0_row3" class="row_heading level0 row3" >COMMERCIAL UNITS</th>
#       <td id="T_26e84_row3_col0" class="data row3 col0" >-0.059080</td>
#       <td id="T_26e84_row3_col1" class="data row3 col1" >-0.025880</td>
#       <td id="T_26e84_row3_col2" class="data row3 col2" >-0.077439</td>
#       <td id="T_26e84_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_26e84_row3_col4" class="data row3 col4" >0.095637</td>
#       <td id="T_26e84_row3_col5" class="data row3 col5" >0.030704</td>
#       <td id="T_26e84_row3_col6" class="data row3 col6" >-0.004361</td>
#     </tr>
#     <tr>
#       <th id="T_26e84_level0_row4" class="row_heading level0 row4" >TOTAL UNITS</th>
#       <td id="T_26e84_row4_col0" class="data row4 col0" >-0.314837</td>
#       <td id="T_26e84_row4_col1" class="data row4 col1" >-0.345113</td>
#       <td id="T_26e84_row4_col2" class="data row4 col2" >0.945345</td>
#       <td id="T_26e84_row4_col3" class="data row4 col3" >0.095637</td>
#       <td id="T_26e84_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_26e84_row4_col5" class="data row4 col5" >0.258934</td>
#       <td id="T_26e84_row4_col6" class="data row4 col6" >0.284246</td>
#     </tr>
#     <tr>
#       <th id="T_26e84_level0_row5" class="row_heading level0 row5" >SALE PRICE</th>
#       <td id="T_26e84_row5_col0" class="data row5 col0" >-0.528620</td>
#       <td id="T_26e84_row5_col1" class="data row5 col1" >-0.617865</td>
#       <td id="T_26e84_row5_col2" class="data row5 col2" >0.270009</td>
#       <td id="T_26e84_row5_col3" class="data row5 col3" >0.030704</td>
#       <td id="T_26e84_row5_col4" class="data row5 col4" >0.258934</td>
#       <td id="T_26e84_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_26e84_row5_col6" class="data row5 col6" >0.882349</td>
#     </tr>
#     <tr>
#       <th id="T_26e84_level0_row6" class="row_heading level0 row6" >lnprice</th>
#       <td id="T_26e84_row6_col0" class="data row6 col0" >-0.450692</td>
#       <td id="T_26e84_row6_col1" class="data row6 col1" >-0.670269</td>
#       <td id="T_26e84_row6_col2" class="data row6 col2" >0.316334</td>
#       <td id="T_26e84_row6_col3" class="data row6 col3" >-0.004361</td>
#       <td id="T_26e84_row6_col4" class="data row6 col4" >0.284246</td>
#       <td id="T_26e84_row6_col5" class="data row6 col5" >0.882349</td>
#       <td id="T_26e84_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
scatter_m(treated_data,numericals)

# %%
treated_rf = rf_train(treated_data, ['LAND SQUARE FEET', 'TOTAL UNITS', 'GROSS SQUARE FEET'], 'lnprice')
# Out:
# R squared for the training data is 0.853
# Score against test data: 0.846

# %%
cv(treated_data, treated_rf, ['LAND SQUARE FEET', 'TOTAL UNITS', 'GROSS SQUARE FEET'], 'lnprice')
# Out:
# Cross validation scores: [0.84466404 0.84632961 0.86113572 0.84135795 0.8279575  0.85293637
#  0.85532311 0.85727005 0.84215551 0.86642699]
# Cross validation mean scores: 0.849555682853014

# %% [markdown]
# # K-Means Clustering

# %%
from scipy.stats import linregress

# Regression line
slope, intercept, r_value, p_value, std_err = linregress(treated_data['LAND SQUARE FEET'], treated_data['lnprice'])

def regression_y(x):
    return slope * x + intercept

plt.scatter(treated_data['LAND SQUARE FEET'], treated_data['lnprice'])
plt.plot(treated_data['LAND SQUARE FEET'], regression_y(treated_data['LAND SQUARE FEET']), 'r')
plt.xlabel('Normalised Land Square Feet')
plt.ylabel('Normalised lnprice')
plt.title("Regression line slope is {} and y-intercept is {}".format(slope, intercept))
# Out:
# Text(0.5, 1.0, 'Regression line slope is -0.6750175711806973 and y-intercept is 0.8105493089117983')

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import completeness_score
from sklearn.metrics import r2_score

treat_copy = treated_data[numericals].copy()

X = treated_data[['LAND SQUARE FEET', 'GROSS SQUARE FEET']]

Y = treated_data['lnprice']

trainX, testX, trainY, testY = train_test_split(X, Y, test_size=0.2)

###fit the whole df so we get true testY vals aswell
model_whole = KMeans(n_clusters=4).fit_predict(treated_data[numericals])


treated_data['clust'] = model_whole


df1 = treated_data[treated_data.clust==0]
df2 = treated_data[treated_data.clust==1]
df3 = treated_data[treated_data.clust==2]
df4 = treated_data[treated_data.clust==3]
#df5 = treated_data[treated_data.clust==4]


plt.scatter(df1['LAND SQUARE FEET'], df1['lnprice'], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(df2['LAND SQUARE FEET'], df2['lnprice'], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(df3['LAND SQUARE FEET'], df3['lnprice'], s = 100,  c = 'green', label = 'Cluster 3')
plt.scatter(df4['LAND SQUARE FEET'], df4['lnprice'], s = 100,  c = 'black', label = 'Cluster 4')
plt.xlabel("lsqf")
plt.ylabel("lnprice")
plt.legend()

final_rf = rf_train(treated_data, ['LAND SQUARE FEET', 'TOTAL UNITS', 'GROSS SQUARE FEET', 'clust'], 'lnprice')
cv(treated_data, final_rf, ['LAND SQUARE FEET', 'TOTAL UNITS', 'GROSS SQUARE FEET', 'clust'], 'lnprice')
# Out:
# R squared for the training data is 0.934
# Score against test data: 0.933
# Cross validation scores: [0.93430074 0.94008572 0.93333121 0.92846324 0.93516902 0.92885006
#  0.92564107 0.93108025 0.93875208 0.93482668]
# Cross validation mean scores: 0.9330500078500019

# %%
from sklearn.metrics import silhouette_score
from sklearn.metrics import mean_squared_error
pca_data = PCA(n_components=2).fit_transform(treat_copy)


mod = KMeans(n_clusters=4).fit_predict(pca_data)
ndf = pd.DataFrame(pca_data)
ndf['clust'] = mod
print(ndf)

ndfg = ndf.groupby('clust')
for n, gdf in ndfg:
    plt.scatter(gdf[0], gdf[1], label=n)
#plt.scatter(pca_2d[:,0], pca_2d[:,1])
plt.title('house clusters')
plt.legend()
plt.show()

print("silhouette coeff",silhouette_score(pca_data, mod))

treated_data['clust2'] = mod

print("\nwith just clust2")
final_rf_c2 = rf_train(treated_data, ['LAND SQUARE FEET', 'TOTAL UNITS', 'GROSS SQUARE FEET', 'clust2'], 'lnprice')
cv(treated_data, final_rf_c2, ['LAND SQUARE FEET', 'TOTAL UNITS', 'GROSS SQUARE FEET', 'clust'], 'lnprice')
print("\nwith both clust1 and clust 2...")
final_rf_c1_c2 = rf_train(treated_data, ['LAND SQUARE FEET', 'TOTAL UNITS', 'GROSS SQUARE FEET', 'clust','clust2'], 'lnprice')
cv(treated_data, final_rf_c1_c2, ['LAND SQUARE FEET', 'TOTAL UNITS', 'GROSS SQUARE FEET', 'clust','clust2'], 'lnprice')


print("\n for each cluster.......\n")
for i in range(4):
    print("Cluster: ",i)
    rfi = rf_train(treated_data.loc[(treated_data['clust']==i) | (treated_data['clust2']==i)], ['LAND SQUARE FEET', 'GROSS SQUARE FEET', 'clust2', 'clust'], 'lnprice')
    print("MSE: ", mean_squared_error(treated_data.loc[(treated_data['clust']==i) | (treated_data['clust2']==i), 'lnprice'], rfi.predict(treated_data[['LAND SQUARE FEET', 'GROSS SQUARE FEET', 'clust2', 'clust']].loc[(treated_data['clust']==i) | (treated_data['clust2']==i)])))
    print("\n ")
# Out:
#               0         1  clust
# 0      0.426389  0.055280      0
# 1      0.297456 -0.055594      2
# 2      0.124303 -0.129967      2
# 3      0.218202 -0.089446      2
# 4      0.295981 -0.056056      2
# ...         ...       ...    ...
# 15406  0.160563 -0.119103      2
# 15407  0.702636  0.065015      0
# 15408  0.753620  0.028310      0
# 15409  0.551617 -0.013883      0
# 15410  0.226977 -0.001796      2
#
# [15411 rows x 3 columns]
# silhouette coeff 0.529251446682952
#
# with just clust2
# R squared for the training data is 0.941
# Score against test data: 0.943
# Cross validation scores: [0.92805992 0.92871605 0.93434669 0.93577404 0.93002691 0.93053827
#  0.93467827 0.93116852 0.93752058 0.9355592 ]
# Cross validation mean scores: 0.9326388448057392
#
# with both clust1 and clust 2...
# R squared for the training data is 0.941
# Score against test data: 0.940
# Cross validation scores: [0.9386758  0.93796471 0.94397323 0.93584666 0.94015812 0.94612504
#  0.93770587 0.94087089 0.93829993 0.94285531]
# Cross validation mean scores: 0.9402475568062604
#
#  for each cluster.......
#
# Cluster:  0
# R squared for the training data is 0.960
# Score against test data: 0.960
# MSE:  0.0013349484845495583
#
#
# Cluster:  1
# R squared for the training data is 0.972
# Score against test data: 0.970
# MSE:  0.0009350642262843184
#
#
# Cluster:  2
# R squared for the training data is 0.767
# Score against test data: 0.710
# MSE:  0.0009444884457856691
#
#
# Cluster:  3
# R squared for the training data is 0.825
# Score against test data: 0.838
# MSE:  0.0036067425126405203

# %%
def elbow(data):
    sse = {}
    for k in range(2, 15, 2):
        kmeans = KMeans(n_clusters=k, max_iter=1000).fit(data)
        print(k, kmeans.inertia_)
        sse[k] = kmeans.inertia_  
        # Inertia: Sum of distances of samples to their closest cluster center
    plt.figure()
    plt.plot(list(sse.keys()), list(sse.values()), linewidth=4)
    plt.xlabel("Number of clusters")
    plt.ylabel("Cost")
    plt.show()
elbow(treated_data[['LAND SQUARE FEET', 'GROSS SQUARE FEET','lnprice','TOTAL UNITS']])
# Out:
# 2 442.7268789548293
# 4 203.6357838180766
# 6 126.74045770726445
# 8 96.77590783769605
# 10 80.57888830004794
# 12 65.80493391209815
# 14 54.727986028540876
